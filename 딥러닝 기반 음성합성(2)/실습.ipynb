# %% [markdown]
# ### 필수 library 설치
# - PyTorch (1.5.1)
# - torchaudio

# %%
# !pip install torch
# !pip install torchaudio
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (1.6.0+cu101)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch) (1.18.5)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch) (0.16.0)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.6/dist-packages (0.6.0)
# Requirement already satisfied: torch==1.6.0 in /usr/local/lib/python3.6/dist-packages (from torchaudio) (1.6.0+cu101)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch==1.6.0->torchaudio) (0.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch==1.6.0->torchaudio) (1.18.5)

# %% [markdown]
# ### Code (WaveGlow)
#
# #### Reference
# - WaveGlow (implemented by NVIDIA): https://github.com/NVIDIA/waveglow
# - 딥러닝을 활용한 음성합성(1) (T-academy): https://tacademy.skplanet.com/live/player/onlineLectureDetail.action?seq=184

# %%
import torch
import torch.nn as nn
import torchaudio
from torch import optim
from torch.utils.data import DataLoader
from torch.distributions.normal import Normal
from torch.autograd import Variable
import torch.nn.functional as F
import numpy as np
import librosa
import os
import argparse
import time, datetime
import json
import gc
from math import pi, log


print('Import 완료')
# Out:
# Import 완료

# %% [markdown]
# ### 0. GPU 체크

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")

if not use_cuda:
    print('Edit - Notebook settings 에서 GPU로 변경해주세요.')

else:
    print('GPU 사용 준비가 완료되었습니다.')
# Out:
# GPU 사용 준비가 완료되었습니다.

# %% [markdown]
# ### 1. Dataset (LJ Speech) 다운로드
#
# This is a public domain speech dataset consisting of 13,100 short audio clips of a single speaker reading passages from 7 non-fiction books. A transcription is provided for each clip. Clips vary in length from 1 to 10 seconds and have a total length of approximately 24 hours.
#
# Link: https://keithito.com/LJ-Speech-Dataset/

# %%
LJSpeech_url = 'https://data.keithito.com/data/speech/LJSpeech-1.1.tar.bz2'
train_dataset = torchaudio.datasets.LJSPEECH("", url=LJSpeech_url, download=True)

print('Download 완료')
# Out:
# Download 완료

# %% [markdown]
# ### 2. Dataset 전처리
#
# 훈련을 위한 데이터셋 전처리를 진행합니다.
#
# LJ speech 음성 데이터에서 mel-spectrogram을 얻은 뒤, 이를 적당한 간격(15872 samples)으로 잘라내어 훈련 데이터 셋을 구성합니다.
#
# LJ speech의 sample rate은 22.05kHz로 15872 samples는 약 0.72초를 모델링하는 것과 같습니다.
#
# Mel-spectrogram은 dynamic_range_compression 함수를 통해 크기를 재조절합니다.

# %%
hop_length = 256
max_steps = 15872

class Collate():
    def __init__(self):
        self.wav_to_mel = torchaudio.transforms.MelSpectrogram(sample_rate=22050, n_mels=80, win_length=1024, hop_length=hop_length, f_min=0.0, f_max=8000.0, n_fft=1024)

    def __call__(self, batch):
        # batch: N_batch * [wav, sample_rate, text, text_normalized]

        x_batch = []
        c_batch = []
        for idx in range(len(batch)):
            x = batch[idx][0].squeeze()
            c = self.wav_to_mel(x)
            c = self.dynamic_range_compression(c)
            
            pad = (x.shape[0] // hop_length + 1) * hop_length - x.shape[0]
            pad_l = pad // 2
            pad_r = pad // 2 + pad % 2

            # zero pad for quantized signal
            x = np.pad(x, (pad_l, pad_r), mode="constant", constant_values=0.0)
            x = torch.tensor(x)

            max_time_frames = max_steps // hop_length
            s = np.random.randint(0, c.shape[1] - max_time_frames)
            ts = s * hop_length
            x = x[ts:ts + hop_length * max_time_frames]
            c = c[:,s:s + max_time_frames]
            
            x_batch.append(x)
            c_batch.append(c)

        x_batch = torch.stack(x_batch)
        c_batch = torch.stack(c_batch)

        return x_batch, c_batch

    def dynamic_range_compression(self, x, C=1, clip_val=1e-5):
        return torch.log(torch.clamp(x, min=clip_val) * C)

collate_fn = Collate()
train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True, drop_last=False, collate_fn=collate_fn)
x_batch, c_batch = next(iter(train_loader))

print('audio batch shape:', x_batch.shape)
print('mel batch shape:', c_batch.shape)
print('Data 전처리 완료')
# Out:
# audio batch shape: torch.Size([8, 15872])
# mel batch shape: torch.Size([8, 80, 62])
# Data 전처리 완료

# %% [markdown]
# ### 3. WaveGlow 구현
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### 3.1 Upsample conv
#
# ConvTranspose1d로 간단히 구현합니다.
#
# in_channels와 out_channels는 mel-spectrogram의 주파수 축 차원과 동일하게 80으로 설정합니다.
#
# mel-spectrogram의 frame 길이는 audio를 temporal axis로 256배 축소한 것으로 설정되어 있습니다.
#
# 따라서 audio의 길이와 동일하게 늘려주기 위하여 stride를 256로 설정하겠습니다.
#
# 또한 주변 frame 값들도 고려하기 위하여 kernel_size를 256보다 큰 1024로 설정하겠습니다.

# %%
class UpsampleConv(nn.Module):
    def __init__(self, n_mel_channels=80):
        super().__init__()
        self.upsample = torch.nn.ConvTranspose1d(n_mel_channels, n_mel_channels, kernel_size=1024, stride=256)

    def forward(self, spect):
        spect = self.upsample(spect)
        return spect

# %% [markdown]
# #### 3.2 Invertible 1x1 Convolution
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1x1 convolution을 구현합니다.
#
# Changing ordering을 대신하는 역할을 수행할 것이므로 bias가 없는 layer를 선언합니다.
#
# 이때 최초 weight 값은 orthonormal basis로 구성합니다.
#
# 채널을 섞을 때 발생하는 log-determinant는 log|detW| 이며, 이를 매 프레임에 대해서 동일하게 적용하므로 최종적인 log-determinant는 batch_size * frame_length * log|detW| 가 됩니다.
#
# 역변환은 W의 역행렬을 구하여 진행합니다.

# %%
class Invertible1x1Conv(torch.nn.Module):
    def __init__(self, c):
        super().__init__()
        self.conv = torch.nn.Conv1d(c, c, kernel_size=1, stride=1, padding=0, bias=False)
        W = torch.qr(torch.FloatTensor(c, c).normal_())[0]
        if torch.det(W) < 0:
            W[:,0] = -1*W[:,0]
        W = W.view(c, c, 1)
        self.conv.weight.data = W

    def forward(self, x, log_det_sum):
        # shape
        z = self.conv(x)
        
        B, _, T = x.size()
        W = self.conv.weight.squeeze()
        log_det_W = B * T * torch.logdet(W)
        log_det_sum = log_det_sum + log_det_W

        return z, log_det_sum

    def reverse(self, z):
        W = self.conv.weight.squeeze()
        W_inverse = W.float().inverse()
        W_inverse = Variable(W_inverse[..., None])
        self.W_inverse = W_inverse
        x = F.conv1d(z, self.W_inverse, bias=None, stride=1, padding=0)
        
        return x

# %% [markdown]
# #### 3.3. Non-causal WaveNet
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Non-causal WaveNet을 구현합니다.
#
# Mel-spectrogram를 local condition으로 하여 affine coupling layer에서 사용될 log_s, t 값을 계산합니다.
#
# Receptive field를 넓게 설정하기 위하여 layer를 쌓으면서 dilation을 2의 배수로 증가시킵니다.
#
# Non-linearity로 tanh - gate unit을 사용합니다.

# %%
class WN(nn.Module):
    """
    This is the WaveNet like layer for the affine coupling.  The primary difference
    from WaveNet is the convolutions need not be causal.  There is also no dilation
    size reset.  The dilation only doubles on each layer
    """
    def __init__(self, in_channels, cin_channels, n_layers=8, n_channels=128,
                 kernel_size=3):
        super(WN, self).__init__()
        assert(kernel_size % 2 == 1)
        assert(n_channels % 2 == 0)
        self.n_layers = n_layers
        self.n_channels = n_channels
        self.in_layers = torch.nn.ModuleList()
        self.res_skip_layers = torch.nn.ModuleList()

        start = torch.nn.Conv1d(in_channels, n_channels, 1)
        start = torch.nn.utils.weight_norm(start, name='weight')
        self.start = start

        # Initializing last layer to 0 makes the affine coupling layers
        # do nothing at first.  This helps with training stability
        end = torch.nn.Conv1d(n_channels, 2*in_channels, 1)
        end.weight.data.zero_()
        end.bias.data.zero_()
        self.end = end

        cond_layer = torch.nn.Conv1d(cin_channels, 2*n_channels*n_layers, 1)
        self.cond_layer = torch.nn.utils.weight_norm(cond_layer, name='weight')

        for i in range(n_layers):
            dilation = 2 ** i
            padding = int((kernel_size*dilation - dilation)/2)
            in_layer = torch.nn.Conv1d(n_channels, 2*n_channels, kernel_size,
                                       dilation=dilation, padding=padding)
            in_layer = torch.nn.utils.weight_norm(in_layer, name='weight')
            self.in_layers.append(in_layer)

            # last one is not necessary
            if i < n_layers - 1:
                res_skip_channels = 2*n_channels
            else:
                res_skip_channels = n_channels
            res_skip_layer = torch.nn.Conv1d(n_channels, res_skip_channels, 1)
            res_skip_layer = torch.nn.utils.weight_norm(res_skip_layer, name='weight')
            self.res_skip_layers.append(res_skip_layer)

    def forward(self, audio, spect):
        audio = self.start(audio)
        output = torch.zeros_like(audio)
        n_channels_tensor = torch.IntTensor([self.n_channels])

        spect = self.cond_layer(spect)

        for i in range(self.n_layers):
            spect_offset = i*2*self.n_channels
            acts = self.fused_add_tanh_sigmoid_multiply(
                self.in_layers[i](audio),
                spect[:,spect_offset:spect_offset+2*self.n_channels,:],
                n_channels_tensor)

            res_skip_acts = self.res_skip_layers[i](acts)
            if i < self.n_layers - 1:
                audio = audio + res_skip_acts[:,:self.n_channels,:]
                output = output + res_skip_acts[:,self.n_channels:,:]
            else:
                output = output + res_skip_acts

        return self.end(output).chunk(2,1)


    def fused_add_tanh_sigmoid_multiply(self, input_a, input_b, n_channels):
        n_channels_int = n_channels[0]
        in_act = input_a+input_b
        t_act = torch.tanh(in_act[:, :n_channels_int, :])
        s_act = torch.sigmoid(in_act[:, n_channels_int:, :])
        acts = t_act * s_act
        return acts

# %% [markdown]
# #### 3.4 Affine coupling layer
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Affine coupling layer를 구현합니다.
#
# input의 절반(x_a)은 변환을 하지 않고, 나머지 절반(x_b)은 affine transform을 적용합니다.
#
# 이때, s와 t는 x_a를 non-causal WaveNet을 통과시켜 얻습니다.
#
# 구현의 편의상 non-causal WaveNet의 출력을 log_s, t로 생각하겠습니다.
#
# Jacobian matrix를 고려하면 determinant는 대각 성분의 곱이 되고,
#
# 최종적인 log-determinant는 sum(log_s)가 됩니다.

# %%
class AffineCouplingLayer(nn.Module):
    def __init__(self, in_channels, cin_channels):
        super().__init__()
        self.WN = WN(in_channels, cin_channels)

    def forward(self, x, c, log_det_sum):

        x_a, x_b = x.chunk(2,1)
        log_s, t = self.WN(x_a, c)
        x_b = torch.exp(log_s) * x_b + t
        log_det_sum = log_det_sum + log_s.sum()
        z = torch.cat((x_a, x_b), dim=1)

        return z, c, log_det_sum

    def reverse(self, z, c):
        z_a, z_b = z.chunk(2,1)
        log_s, t = self.WN(z_a, c)
        z_b = torch.exp(-log_s) * (z_b - t)

        x = torch.cat((z_a, z_b), dim=1)

        return x, c

# %% [markdown]
# #### 3. WaveGlow 최종 모델

# %%
class WaveGlow(torch.nn.Module):
    def __init__(self, n_mel_channels=80, n_flows=12, n_group=8, n_early_every=4,
                 n_early_size=2):
        super(WaveGlow, self).__init__()

        self.upsample = UpsampleConv(n_mel_channels)
        assert(n_group % 2 == 0)
        self.n_flows = n_flows
        self.n_group = n_group
        self.n_early_every = n_early_every
        self.n_early_size = n_early_size
        self.coupling_layer = torch.nn.ModuleList()
        self.convinv = torch.nn.ModuleList()
        self.sigma = 1.0

        n_half = int(n_group/2)

        # Set up layers with the right sizes based on how many dimensions
        # have been output already
        n_remaining_channels = n_group
        for k in range(n_flows):
            if k % self.n_early_every == 0 and k > 0:
                n_half = n_half - int(self.n_early_size/2)
                n_remaining_channels = n_remaining_channels - self.n_early_size
            self.convinv.append(Invertible1x1Conv(n_remaining_channels))
            self.coupling_layer.append(AffineCouplingLayer(n_half, n_mel_channels*n_group))
        self.n_remaining_channels = n_remaining_channels  # Useful during inference

    def forward(self, audio, spect):
        audio = audio.squeeze(1)

        #  Upsample spectrogram to size of audio
        spect = self.upsample(spect)
        assert(spect.size(2) >= audio.size(1))
        if spect.size(2) > audio.size(1):
            spect = spect[:, :, :audio.size(1)]

        spect = spect.unfold(2, self.n_group, self.n_group).permute(0, 2, 1, 3)
        spect = spect.contiguous().view(spect.size(0), spect.size(1), -1).permute(0, 2, 1)

        audio = audio.unfold(1, self.n_group, self.n_group).permute(0, 2, 1)

        output_audio = []
        log_det_sum = 0.0

        for k in range(self.n_flows):
            if k % self.n_early_every == 0 and k > 0:
                output_audio.append(audio[:,:self.n_early_size,:])
                audio = audio[:,self.n_early_size:,:]
            audio, log_det_sum = self.convinv[k](audio, log_det_sum)
            audio, spect, log_det_sum = self.coupling_layer[k](audio, spect, log_det_sum)

        output_audio.append(audio)

        z = torch.cat(output_audio,1)

        log_p = 0.5 * (- log(2.0 * pi) - z.pow(2)).sum() / (z.size(0)*z.size(1)*z.size(2))
        log_det = log_det_sum /  (z.size(0)*z.size(1)*z.size(2))
        
        return log_p, log_det

# %% [markdown]
# #### 4. 모델 및 옵티마이저 선언

# %%
model = WaveGlow().to(device)
learning_rate = 1e-3
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# ### 5. 훈련 진행

# %%
iteration = 0

for epoch in range(100):
  print("Epoch: {}".format(epoch))
  for i, (x, c) in enumerate(train_loader):
    start = time.perf_counter()
    model.zero_grad()
    x, c = x.to(device), c.to(device)
    log_p, logdet = model(x, c)
    log_p, logdet = torch.mean(log_p), torch.mean(logdet)

    loss = -(log_p + logdet)
    loss.backward()
    nn.utils.clip_grad_norm_(model.parameters(), 1.)
    
    optimizer.step()

    duration = time.perf_counter() - start
    print("Iteratoin: {}, [NLL, Log p(z), Log Det]: [{:.4f}, {:.4f}, {:.4f}], {:.2f}s/it".format(iteration, loss.item(), log_p.item(), logdet.item(), duration))
    
    iteration += 1
# Out:
# Streaming output truncated to the last 5000 lines.
# Iteratoin: 2630, [NLL, Log p(z), Log Det]: [-4.2459, -1.3666, 5.6124], 3.34s/it
# Iteratoin: 2631, [NLL, Log p(z), Log Det]: [-4.3606, -1.3846, 5.7452], 3.36s/it
# Iteratoin: 2632, [NLL, Log p(z), Log Det]: [-3.8484, -1.4241, 5.2725], 3.38s/it
# Iteratoin: 2633, [NLL, Log p(z), Log Det]: [-4.2265, -1.3728, 5.5993], 3.37s/it
# Iteratoin: 2634, [NLL, Log p(z), Log Det]: [-3.8327, -1.4778, 5.3105], 3.36s/it
# Iteratoin: 2635, [NLL, Log p(z), Log Det]: [-4.2775, -1.4050, 5.6825], 3.33s/it
# Iteratoin: 2636, [NLL, Log p(z), Log Det]: [-4.1696, -1.3867, 5.5563], 3.37s/it
# Iteratoin: 2637, [NLL, Log p(z), Log Det]: [-4.0370, -1.4250, 5.4620], 3.37s/it
# Iteratoin: 2638, [NLL, Log p(z), Log Det]: [-4.0769, -1.4232, 5.5001], 3.36s/it
# Iteratoin: 2639, [NLL, Log p(z), Log Det]: [-3.9943, -1.4460, 5.4403], 3.33s/it
# Iteratoin: 2640, [NLL, Log p(z), Log Det]: [-3.8734, -1.4659, 5.3394], 3.35s/it
# Iteratoin: 2641, [NLL, Log p(z), Log Det]: [-4.1648, -1.4265, 5.5913], 3.37s/it
# Iteratoin: 2642, [NLL, Log p(z), Log Det]: [-3.8296, -1.4319, 5.2614], 3.35s/it
# Iteratoin: 2643, [NLL, Log p(z), Log Det]: [-4.0151, -1.3592, 5.3742], 3.34s/it
# Iteratoin: 2644, [NLL, Log p(z), Log Det]: [-4.1085, -1.3668, 5.4754], 3.37s/it
# Iteratoin: 2645, [NLL, Log p(z), Log Det]: [-3.8086, -1.4153, 5.2239], 3.36s/it
# Iteratoin: 2646, [NLL, Log p(z), Log Det]: [-4.6202, -1.4217, 6.0419], 3.34s/it
# Iteratoin: 2647, [NLL, Log p(z), Log Det]: [-4.1449, -1.4234, 5.5682], 3.34s/it
# Iteratoin: 2648, [NLL, Log p(z), Log Det]: [-3.9577, -1.4049, 5.3626], 3.34s/it
# Iteratoin: 2649, [NLL, Log p(z), Log Det]: [-4.1653, -1.4134, 5.5787], 3.35s/it
# Iteratoin: 2650, [NLL, Log p(z), Log Det]: [-4.1859, -1.3660, 5.5519], 3.36s/it
# Iteratoin: 2651, [NLL, Log p(z), Log Det]: [-4.1791, -1.4405, 5.6196], 3.35s/it
# Iteratoin: 2652, [NLL, Log p(z), Log Det]: [-4.3895, -1.4593, 5.8488], 3.37s/it
# Iteratoin: 2653, [NLL, Log p(z), Log Det]: [-4.1705, -1.4658, 5.6362], 3.37s/it
# Iteratoin: 2654, [NLL, Log p(z), Log Det]: [-4.1927, -1.3766, 5.5692], 3.34s/it
# Iteratoin: 2655, [NLL, Log p(z), Log Det]: [-3.8734, -1.3817, 5.2551], 3.37s/it
# Iteratoin: 2656, [NLL, Log p(z), Log Det]: [-4.2452, -1.3934, 5.6386], 3.37s/it
# Iteratoin: 2657, [NLL, Log p(z), Log Det]: [-3.9768, -1.4205, 5.3972], 3.37s/it
# Iteratoin: 2658, [NLL, Log p(z), Log Det]: [-3.9041, -1.4170, 5.3212], 3.37s/it
# Iteratoin: 2659, [NLL, Log p(z), Log Det]: [-4.2974, -1.4502, 5.7476], 3.37s/it
# Iteratoin: 2660, [NLL, Log p(z), Log Det]: [-4.1002, -1.4057, 5.5059], 3.38s/it
# Iteratoin: 2661, [NLL, Log p(z), Log Det]: [-4.4733, -1.4231, 5.8965], 3.38s/it
# Iteratoin: 2662, [NLL, Log p(z), Log Det]: [-4.5099, -1.4197, 5.9296], 3.37s/it
# Iteratoin: 2663, [NLL, Log p(z), Log Det]: [-4.2284, -1.3952, 5.6236], 3.35s/it
# Iteratoin: 2664, [NLL, Log p(z), Log Det]: [-4.4288, -1.3465, 5.7754], 3.38s/it
# Iteratoin: 2665, [NLL, Log p(z), Log Det]: [-4.0530, -1.4342, 5.4872], 3.39s/it
# Iteratoin: 2666, [NLL, Log p(z), Log Det]: [-4.3865, -1.3916, 5.7781], 3.42s/it
# Iteratoin: 2667, [NLL, Log p(z), Log Det]: [-4.1998, -1.3718, 5.5716], 3.46s/it
# Iteratoin: 2668, [NLL, Log p(z), Log Det]: [-4.4053, -1.3535, 5.7588], 3.47s/it
# Iteratoin: 2669, [NLL, Log p(z), Log Det]: [-4.1961, -1.3728, 5.5689], 3.46s/it
# Iteratoin: 2670, [NLL, Log p(z), Log Det]: [-4.1043, -1.3796, 5.4840], 3.45s/it
# Iteratoin: 2671, [NLL, Log p(z), Log Det]: [-4.2419, -1.4537, 5.6956], 3.46s/it
# Iteratoin: 2672, [NLL, Log p(z), Log Det]: [-4.0695, -1.4199, 5.4894], 3.49s/it
# Iteratoin: 2673, [NLL, Log p(z), Log Det]: [-4.5397, -1.3814, 5.9210], 3.43s/it
# Iteratoin: 2674, [NLL, Log p(z), Log Det]: [-3.8728, -1.3996, 5.2724], 3.47s/it
# Iteratoin: 2675, [NLL, Log p(z), Log Det]: [-4.2052, -1.3906, 5.5958], 3.43s/it
# Iteratoin: 2676, [NLL, Log p(z), Log Det]: [-4.0293, -1.4380, 5.4673], 3.50s/it
# Iteratoin: 2677, [NLL, Log p(z), Log Det]: [-4.5293, -1.3706, 5.8999], 3.45s/it
# Iteratoin: 2678, [NLL, Log p(z), Log Det]: [-4.1203, -1.4542, 5.5745], 3.45s/it
# Iteratoin: 2679, [NLL, Log p(z), Log Det]: [-4.2574, -1.4567, 5.7141], 3.44s/it
# Iteratoin: 2680, [NLL, Log p(z), Log Det]: [-4.1855, -1.4013, 5.5868], 3.47s/it
# Iteratoin: 2681, [NLL, Log p(z), Log Det]: [-4.4484, -1.3765, 5.8249], 3.46s/it
# Iteratoin: 2682, [NLL, Log p(z), Log Det]: [-4.2530, -1.4253, 5.6783], 3.45s/it
# Iteratoin: 2683, [NLL, Log p(z), Log Det]: [-4.0402, -1.4473, 5.4875], 3.46s/it
# Iteratoin: 2684, [NLL, Log p(z), Log Det]: [-4.4887, -1.3911, 5.8798], 3.48s/it
# Iteratoin: 2685, [NLL, Log p(z), Log Det]: [-3.9485, -1.5347, 5.4833], 3.46s/it
# Iteratoin: 2686, [NLL, Log p(z), Log Det]: [-3.9792, -1.5227, 5.5019], 3.45s/it
# Iteratoin: 2687, [NLL, Log p(z), Log Det]: [-4.0376, -1.3827, 5.4203], 3.46s/it
# Iteratoin: 2688, [NLL, Log p(z), Log Det]: [-4.3291, -1.3276, 5.6567], 3.46s/it
# Iteratoin: 2689, [NLL, Log p(z), Log Det]: [-3.8241, -1.3661, 5.1902], 3.43s/it
# Iteratoin: 2690, [NLL, Log p(z), Log Det]: [-4.1516, -1.3878, 5.5394], 3.47s/it
# Iteratoin: 2691, [NLL, Log p(z), Log Det]: [-3.9824, -1.3941, 5.3765], 3.45s/it
# Iteratoin: 2692, [NLL, Log p(z), Log Det]: [-4.3197, -1.4112, 5.7309], 3.48s/it
# Iteratoin: 2693, [NLL, Log p(z), Log Det]: [-4.2886, -1.4008, 5.6894], 3.44s/it
# Iteratoin: 2694, [NLL, Log p(z), Log Det]: [-4.3159, -1.3835, 5.6994], 3.45s/it
# Iteratoin: 2695, [NLL, Log p(z), Log Det]: [-4.3754, -1.3630, 5.7384], 3.44s/it
# Iteratoin: 2696, [NLL, Log p(z), Log Det]: [-4.0181, -1.4125, 5.4305], 3.48s/it
# Iteratoin: 2697, [NLL, Log p(z), Log Det]: [-4.0318, -1.3778, 5.4096], 3.44s/it
# Iteratoin: 2698, [NLL, Log p(z), Log Det]: [-4.1401, -1.3778, 5.5179], 3.47s/it
# Iteratoin: 2699, [NLL, Log p(z), Log Det]: [-4.4074, -1.4315, 5.8389], 3.43s/it
# Iteratoin: 2700, [NLL, Log p(z), Log Det]: [-4.4337, -1.5282, 5.9619], 3.47s/it
# Iteratoin: 2701, [NLL, Log p(z), Log Det]: [-4.1031, -1.4987, 5.6018], 3.46s/it
# Iteratoin: 2702, [NLL, Log p(z), Log Det]: [-3.7336, -1.4215, 5.1550], 3.44s/it
# Iteratoin: 2703, [NLL, Log p(z), Log Det]: [-4.1675, -1.3572, 5.5247], 3.45s/it
# Iteratoin: 2704, [NLL, Log p(z), Log Det]: [-4.1757, -1.4031, 5.5788], 3.49s/it
# Iteratoin: 2705, [NLL, Log p(z), Log Det]: [-4.1395, -1.4032, 5.5427], 3.46s/it
# Iteratoin: 2706, [NLL, Log p(z), Log Det]: [-3.9377, -1.4005, 5.3382], 3.43s/it
# Iteratoin: 2707, [NLL, Log p(z), Log Det]: [-3.8927, -1.4197, 5.3124], 3.47s/it
# Iteratoin: 2708, [NLL, Log p(z), Log Det]: [-4.1400, -1.4314, 5.5715], 3.47s/it
# Iteratoin: 2709, [NLL, Log p(z), Log Det]: [-4.2401, -1.5074, 5.7476], 3.46s/it
# Iteratoin: 2710, [NLL, Log p(z), Log Det]: [-4.4916, -1.4246, 5.9161], 3.45s/it
# Iteratoin: 2711, [NLL, Log p(z), Log Det]: [-3.8556, -1.4559, 5.3115], 3.44s/it
# Iteratoin: 2712, [NLL, Log p(z), Log Det]: [-4.0925, -1.3846, 5.4770], 3.46s/it
# Iteratoin: 2713, [NLL, Log p(z), Log Det]: [-4.0854, -1.3987, 5.4841], 3.46s/it
# Iteratoin: 2714, [NLL, Log p(z), Log Det]: [-4.3441, -1.4027, 5.7468], 3.45s/it
# Iteratoin: 2715, [NLL, Log p(z), Log Det]: [-3.8230, -1.3877, 5.2107], 3.43s/it
# Iteratoin: 2716, [NLL, Log p(z), Log Det]: [-3.9456, -1.3803, 5.3259], 3.47s/it
# Iteratoin: 2717, [NLL, Log p(z), Log Det]: [-4.2076, -1.3603, 5.5679], 3.46s/it
# Iteratoin: 2718, [NLL, Log p(z), Log Det]: [-4.3267, -1.4151, 5.7418], 3.43s/it
# Iteratoin: 2719, [NLL, Log p(z), Log Det]: [-4.2881, -1.4034, 5.6915], 3.43s/it
# Iteratoin: 2720, [NLL, Log p(z), Log Det]: [-4.4021, -1.4605, 5.8626], 3.48s/it
# Iteratoin: 2721, [NLL, Log p(z), Log Det]: [-4.2150, -1.4839, 5.6989], 3.46s/it
# Iteratoin: 2722, [NLL, Log p(z), Log Det]: [-4.1838, -1.4428, 5.6266], 3.45s/it
# Iteratoin: 2723, [NLL, Log p(z), Log Det]: [-4.4337, -1.3856, 5.8192], 3.44s/it
# Iteratoin: 2724, [NLL, Log p(z), Log Det]: [-4.3967, -1.3675, 5.7642], 3.50s/it
# Iteratoin: 2725, [NLL, Log p(z), Log Det]: [-3.8691, -1.3843, 5.2534], 3.43s/it
# Iteratoin: 2726, [NLL, Log p(z), Log Det]: [-4.0568, -1.4149, 5.4718], 3.45s/it
# Iteratoin: 2727, [NLL, Log p(z), Log Det]: [-4.6691, -1.3065, 5.9757], 3.44s/it
# Iteratoin: 2728, [NLL, Log p(z), Log Det]: [-4.1464, -1.3658, 5.5122], 3.48s/it
# Iteratoin: 2729, [NLL, Log p(z), Log Det]: [-4.3859, -1.3761, 5.7620], 3.47s/it
# Iteratoin: 2730, [NLL, Log p(z), Log Det]: [-4.4610, -1.4075, 5.8685], 3.46s/it
# Iteratoin: 2731, [NLL, Log p(z), Log Det]: [-3.9826, -1.4548, 5.4374], 3.46s/it
# Iteratoin: 2732, [NLL, Log p(z), Log Det]: [-4.6163, -1.4575, 6.0739], 3.46s/it
# Iteratoin: 2733, [NLL, Log p(z), Log Det]: [-4.3341, -1.4121, 5.7462], 3.44s/it
# Iteratoin: 2734, [NLL, Log p(z), Log Det]: [-4.6373, -1.4544, 6.0917], 3.43s/it
# Iteratoin: 2735, [NLL, Log p(z), Log Det]: [-4.8598, -1.3933, 6.2532], 3.46s/it
# Iteratoin: 2736, [NLL, Log p(z), Log Det]: [-4.0843, -1.4016, 5.4860], 3.49s/it
# Iteratoin: 2737, [NLL, Log p(z), Log Det]: [-4.4444, -1.4158, 5.8602], 3.44s/it
# Iteratoin: 2738, [NLL, Log p(z), Log Det]: [-3.9964, -1.4105, 5.4069], 3.45s/it
# Iteratoin: 2739, [NLL, Log p(z), Log Det]: [-4.3482, -1.4027, 5.7508], 3.44s/it
# Iteratoin: 2740, [NLL, Log p(z), Log Det]: [-4.4200, -1.3907, 5.8108], 3.48s/it
# Iteratoin: 2741, [NLL, Log p(z), Log Det]: [-3.9039, -1.4250, 5.3288], 3.48s/it
# Iteratoin: 2742, [NLL, Log p(z), Log Det]: [-4.1228, -1.4120, 5.5349], 3.46s/it
# Iteratoin: 2743, [NLL, Log p(z), Log Det]: [-4.0814, -1.4285, 5.5099], 3.44s/it
# Iteratoin: 2744, [NLL, Log p(z), Log Det]: [-4.2759, -1.4472, 5.7231], 3.46s/it
# Iteratoin: 2745, [NLL, Log p(z), Log Det]: [-3.7159, -1.4608, 5.1767], 3.47s/it
# Iteratoin: 2746, [NLL, Log p(z), Log Det]: [-4.0546, -1.3673, 5.4219], 3.48s/it
# Iteratoin: 2747, [NLL, Log p(z), Log Det]: [-4.1799, -1.4154, 5.5953], 3.46s/it
# Iteratoin: 2748, [NLL, Log p(z), Log Det]: [-4.5282, -1.3852, 5.9133], 3.46s/it
# Iteratoin: 2749, [NLL, Log p(z), Log Det]: [-4.1184, -1.4145, 5.5329], 3.46s/it
# Iteratoin: 2750, [NLL, Log p(z), Log Det]: [-4.1440, -1.4144, 5.5584], 3.47s/it
# Iteratoin: 2751, [NLL, Log p(z), Log Det]: [-3.9946, -1.4045, 5.3991], 3.44s/it
# Iteratoin: 2752, [NLL, Log p(z), Log Det]: [-4.1042, -1.4234, 5.5275], 3.49s/it
# Iteratoin: 2753, [NLL, Log p(z), Log Det]: [-4.3256, -1.4146, 5.7402], 3.46s/it
# Iteratoin: 2754, [NLL, Log p(z), Log Det]: [-4.3590, -1.4448, 5.8038], 3.44s/it
# Iteratoin: 2755, [NLL, Log p(z), Log Det]: [-4.2424, -1.4572, 5.6997], 3.43s/it
# Iteratoin: 2756, [NLL, Log p(z), Log Det]: [-4.2659, -1.4389, 5.7048], 3.48s/it
# Iteratoin: 2757, [NLL, Log p(z), Log Det]: [-4.1321, -1.3982, 5.5304], 3.46s/it
# Iteratoin: 2758, [NLL, Log p(z), Log Det]: [-4.1118, -1.4592, 5.5710], 3.44s/it
# Iteratoin: 2759, [NLL, Log p(z), Log Det]: [-4.1349, -1.4268, 5.5617], 3.44s/it
# Iteratoin: 2760, [NLL, Log p(z), Log Det]: [-4.0698, -1.3283, 5.3980], 3.46s/it
# Iteratoin: 2761, [NLL, Log p(z), Log Det]: [-3.7613, -1.3698, 5.1311], 3.45s/it
# Iteratoin: 2762, [NLL, Log p(z), Log Det]: [-4.1014, -1.3689, 5.4703], 3.45s/it
# Iteratoin: 2763, [NLL, Log p(z), Log Det]: [-4.3621, -1.3895, 5.7516], 3.45s/it
# Iteratoin: 2764, [NLL, Log p(z), Log Det]: [-4.3190, -1.5015, 5.8204], 3.48s/it
# Iteratoin: 2765, [NLL, Log p(z), Log Det]: [-4.1339, -1.4655, 5.5995], 3.46s/it
# Iteratoin: 2766, [NLL, Log p(z), Log Det]: [-4.3123, -1.4435, 5.7558], 3.43s/it
# Iteratoin: 2767, [NLL, Log p(z), Log Det]: [-4.3065, -1.4470, 5.7535], 3.46s/it
# Iteratoin: 2768, [NLL, Log p(z), Log Det]: [-3.9519, -1.4260, 5.3780], 3.46s/it
# Iteratoin: 2769, [NLL, Log p(z), Log Det]: [-4.3769, -1.3669, 5.7438], 3.45s/it
# Iteratoin: 2770, [NLL, Log p(z), Log Det]: [-4.2426, -1.3816, 5.6242], 3.39s/it
# Iteratoin: 2771, [NLL, Log p(z), Log Det]: [-4.1486, -1.3723, 5.5208], 3.36s/it
# Iteratoin: 2772, [NLL, Log p(z), Log Det]: [-4.0290, -1.3483, 5.3772], 3.40s/it
# Iteratoin: 2773, [NLL, Log p(z), Log Det]: [-4.0259, -1.3593, 5.3852], 3.37s/it
# Iteratoin: 2774, [NLL, Log p(z), Log Det]: [-4.4514, -1.3939, 5.8453], 3.38s/it
# Iteratoin: 2775, [NLL, Log p(z), Log Det]: [-4.5658, -1.4242, 5.9900], 3.35s/it
# Iteratoin: 2776, [NLL, Log p(z), Log Det]: [-4.2220, -1.4609, 5.6829], 3.38s/it
# Iteratoin: 2777, [NLL, Log p(z), Log Det]: [-4.3987, -1.4406, 5.8393], 3.39s/it
# Iteratoin: 2778, [NLL, Log p(z), Log Det]: [-4.0300, -1.4668, 5.4967], 3.38s/it
# Iteratoin: 2779, [NLL, Log p(z), Log Det]: [-4.2010, -1.4106, 5.6117], 3.35s/it
# Iteratoin: 2780, [NLL, Log p(z), Log Det]: [-4.1684, -1.4555, 5.6239], 3.40s/it
# Iteratoin: 2781, [NLL, Log p(z), Log Det]: [-4.3745, -1.4316, 5.8061], 3.37s/it
# Iteratoin: 2782, [NLL, Log p(z), Log Det]: [-4.1790, -1.4035, 5.5825], 3.37s/it
# Iteratoin: 2783, [NLL, Log p(z), Log Det]: [-4.0016, -1.3725, 5.3742], 3.36s/it
# Iteratoin: 2784, [NLL, Log p(z), Log Det]: [-4.4168, -1.4123, 5.8291], 3.40s/it
# Iteratoin: 2785, [NLL, Log p(z), Log Det]: [-4.3465, -1.4301, 5.7766], 3.42s/it
# Iteratoin: 2786, [NLL, Log p(z), Log Det]: [-4.3096, -1.4782, 5.7878], 3.38s/it
# Iteratoin: 2787, [NLL, Log p(z), Log Det]: [-4.3354, -1.4468, 5.7822], 3.36s/it
# Iteratoin: 2788, [NLL, Log p(z), Log Det]: [-4.6403, -1.4360, 6.0763], 3.38s/it
# Iteratoin: 2789, [NLL, Log p(z), Log Det]: [-4.3998, -1.4762, 5.8760], 3.38s/it
# Iteratoin: 2790, [NLL, Log p(z), Log Det]: [-4.2183, -1.4288, 5.6471], 3.37s/it
# Iteratoin: 2791, [NLL, Log p(z), Log Det]: [-4.2569, -1.3960, 5.6529], 3.37s/it
# Iteratoin: 2792, [NLL, Log p(z), Log Det]: [-4.4768, -1.3927, 5.8695], 3.40s/it
# Iteratoin: 2793, [NLL, Log p(z), Log Det]: [-4.4827, -1.3644, 5.8471], 3.38s/it
# Iteratoin: 2794, [NLL, Log p(z), Log Det]: [-4.3958, -1.3818, 5.7776], 3.38s/it
# Iteratoin: 2795, [NLL, Log p(z), Log Det]: [-4.2440, -1.4004, 5.6444], 3.36s/it
# Iteratoin: 2796, [NLL, Log p(z), Log Det]: [-3.9693, -1.4739, 5.4431], 3.38s/it
# Iteratoin: 2797, [NLL, Log p(z), Log Det]: [-3.9397, -1.4568, 5.3966], 3.37s/it
# Iteratoin: 2798, [NLL, Log p(z), Log Det]: [-4.2054, -1.4049, 5.6103], 3.37s/it
# Iteratoin: 2799, [NLL, Log p(z), Log Det]: [-4.0378, -1.4186, 5.4564], 3.36s/it
# Iteratoin: 2800, [NLL, Log p(z), Log Det]: [-4.5988, -1.3443, 5.9432], 3.39s/it
# Iteratoin: 2801, [NLL, Log p(z), Log Det]: [-4.2573, -1.3838, 5.6411], 3.38s/it
# Iteratoin: 2802, [NLL, Log p(z), Log Det]: [-4.2009, -1.4241, 5.6250], 3.40s/it
# Iteratoin: 2803, [NLL, Log p(z), Log Det]: [-4.2783, -1.4431, 5.7215], 3.36s/it
# Iteratoin: 2804, [NLL, Log p(z), Log Det]: [-4.2022, -1.3961, 5.5983], 3.39s/it
# Iteratoin: 2805, [NLL, Log p(z), Log Det]: [-4.3885, -1.3756, 5.7640], 3.37s/it
# Iteratoin: 2806, [NLL, Log p(z), Log Det]: [-4.3094, -1.4334, 5.7428], 3.37s/it
# Iteratoin: 2807, [NLL, Log p(z), Log Det]: [-4.6315, -1.3637, 5.9953], 3.36s/it
# Iteratoin: 2808, [NLL, Log p(z), Log Det]: [-4.5958, -1.3764, 5.9722], 3.38s/it
# Iteratoin: 2809, [NLL, Log p(z), Log Det]: [-4.1168, -1.4345, 5.5513], 3.38s/it
# Iteratoin: 2810, [NLL, Log p(z), Log Det]: [-4.6530, -1.4138, 6.0667], 3.43s/it
# Iteratoin: 2811, [NLL, Log p(z), Log Det]: [-4.2657, -1.4442, 5.7099], 3.35s/it
# Iteratoin: 2812, [NLL, Log p(z), Log Det]: [-4.4955, -1.4020, 5.8974], 3.41s/it
# Iteratoin: 2813, [NLL, Log p(z), Log Det]: [-4.4453, -1.4128, 5.8581], 3.40s/it
# Iteratoin: 2814, [NLL, Log p(z), Log Det]: [-3.9072, -1.4070, 5.3142], 3.38s/it
# Iteratoin: 2815, [NLL, Log p(z), Log Det]: [-4.1834, -1.4499, 5.6333], 3.37s/it
# Iteratoin: 2816, [NLL, Log p(z), Log Det]: [-4.2061, -1.4082, 5.6143], 3.39s/it
# Iteratoin: 2817, [NLL, Log p(z), Log Det]: [-4.5042, -1.3961, 5.9004], 3.39s/it
# Iteratoin: 2818, [NLL, Log p(z), Log Det]: [-4.5379, -1.4425, 5.9804], 3.36s/it
# Iteratoin: 2819, [NLL, Log p(z), Log Det]: [-3.9828, -1.4364, 5.4192], 3.36s/it
# Iteratoin: 2820, [NLL, Log p(z), Log Det]: [-4.4201, -1.3851, 5.8051], 3.39s/it
# Iteratoin: 2821, [NLL, Log p(z), Log Det]: [-4.1941, -1.4211, 5.6152], 3.38s/it
# Iteratoin: 2822, [NLL, Log p(z), Log Det]: [-3.9849, -1.4612, 5.4460], 3.38s/it
# Iteratoin: 2823, [NLL, Log p(z), Log Det]: [-4.0345, -1.3997, 5.4342], 3.37s/it
# Iteratoin: 2824, [NLL, Log p(z), Log Det]: [-4.3829, -1.3963, 5.7792], 3.40s/it
# Iteratoin: 2825, [NLL, Log p(z), Log Det]: [-4.1490, -1.4301, 5.5790], 3.43s/it
# Iteratoin: 2826, [NLL, Log p(z), Log Det]: [-4.3084, -1.4456, 5.7539], 3.39s/it
# Iteratoin: 2827, [NLL, Log p(z), Log Det]: [-4.4941, -1.4297, 5.9238], 3.37s/it
# Iteratoin: 2828, [NLL, Log p(z), Log Det]: [-3.9454, -1.4721, 5.4175], 3.41s/it
# Iteratoin: 2829, [NLL, Log p(z), Log Det]: [-4.4432, -1.4081, 5.8514], 3.40s/it
# Iteratoin: 2830, [NLL, Log p(z), Log Det]: [-4.4145, -1.4547, 5.8692], 3.40s/it
# Iteratoin: 2831, [NLL, Log p(z), Log Det]: [-4.2227, -1.4444, 5.6671], 3.41s/it
# Iteratoin: 2832, [NLL, Log p(z), Log Det]: [-4.3145, -1.4040, 5.7184], 3.47s/it
# Iteratoin: 2833, [NLL, Log p(z), Log Det]: [-4.1461, -1.3794, 5.5255], 3.45s/it
# Iteratoin: 2834, [NLL, Log p(z), Log Det]: [-3.9768, -1.3540, 5.3308], 3.45s/it
# Iteratoin: 2835, [NLL, Log p(z), Log Det]: [-4.1416, -1.4033, 5.5449], 3.44s/it
# Iteratoin: 2836, [NLL, Log p(z), Log Det]: [-4.1296, -1.4202, 5.5497], 3.51s/it
# Iteratoin: 2837, [NLL, Log p(z), Log Det]: [-4.1587, -1.4874, 5.6461], 3.48s/it
# Iteratoin: 2838, [NLL, Log p(z), Log Det]: [-4.1198, -1.5820, 5.7018], 3.45s/it
# Iteratoin: 2839, [NLL, Log p(z), Log Det]: [-3.9769, -1.4856, 5.4626], 3.46s/it
# Iteratoin: 2840, [NLL, Log p(z), Log Det]: [-4.3488, -1.4539, 5.8026], 3.48s/it
# Iteratoin: 2841, [NLL, Log p(z), Log Det]: [-4.2423, -1.4974, 5.7397], 3.45s/it
# Iteratoin: 2842, [NLL, Log p(z), Log Det]: [-3.8232, -1.4008, 5.2240], 3.46s/it
# Iteratoin: 2843, [NLL, Log p(z), Log Det]: [-4.1816, -1.3805, 5.5620], 3.45s/it
# Iteratoin: 2844, [NLL, Log p(z), Log Det]: [-4.6626, -1.3466, 6.0092], 3.47s/it
# Iteratoin: 2845, [NLL, Log p(z), Log Det]: [-4.8375, -1.3693, 6.2068], 3.45s/it
# Iteratoin: 2846, [NLL, Log p(z), Log Det]: [-4.6089, -1.5745, 6.1834], 3.45s/it
# Iteratoin: 2847, [NLL, Log p(z), Log Det]: [-3.7572, -1.6235, 5.3807], 3.46s/it
# Iteratoin: 2848, [NLL, Log p(z), Log Det]: [-4.0166, -1.5093, 5.5259], 3.48s/it
# Iteratoin: 2849, [NLL, Log p(z), Log Det]: [-4.4014, -1.3981, 5.7995], 3.45s/it
# Iteratoin: 2850, [NLL, Log p(z), Log Det]: [-4.1128, -1.3415, 5.4542], 3.47s/it
# Iteratoin: 2851, [NLL, Log p(z), Log Det]: [-3.9519, -1.3743, 5.3262], 3.44s/it
# Iteratoin: 2852, [NLL, Log p(z), Log Det]: [-3.8872, -1.3390, 5.2262], 3.46s/it
# Iteratoin: 2853, [NLL, Log p(z), Log Det]: [-4.1159, -1.3697, 5.4855], 3.46s/it
# Iteratoin: 2854, [NLL, Log p(z), Log Det]: [-3.9244, -1.4045, 5.3289], 3.45s/it
# Iteratoin: 2855, [NLL, Log p(z), Log Det]: [-4.1210, -1.4252, 5.5462], 3.47s/it
# Iteratoin: 2856, [NLL, Log p(z), Log Det]: [-3.9978, -1.4551, 5.4529], 3.46s/it
# Iteratoin: 2857, [NLL, Log p(z), Log Det]: [-3.9032, -1.4881, 5.3913], 3.46s/it
# Iteratoin: 2858, [NLL, Log p(z), Log Det]: [-4.0263, -1.3800, 5.4063], 3.44s/it
# Iteratoin: 2859, [NLL, Log p(z), Log Det]: [-4.4488, -1.3739, 5.8227], 3.43s/it
# Iteratoin: 2860, [NLL, Log p(z), Log Det]: [-4.3033, -1.4133, 5.7166], 3.47s/it
# Iteratoin: 2861, [NLL, Log p(z), Log Det]: [-4.0636, -1.4348, 5.4984], 3.44s/it
# Iteratoin: 2862, [NLL, Log p(z), Log Det]: [-3.9071, -1.4248, 5.3319], 3.46s/it
# Iteratoin: 2863, [NLL, Log p(z), Log Det]: [-4.3212, -1.3907, 5.7120], 3.48s/it
# Iteratoin: 2864, [NLL, Log p(z), Log Det]: [-4.0658, -1.4320, 5.4978], 3.47s/it
# Iteratoin: 2865, [NLL, Log p(z), Log Det]: [-4.1617, -1.4175, 5.5792], 3.44s/it
# Iteratoin: 2866, [NLL, Log p(z), Log Det]: [-4.3139, -1.4480, 5.7619], 3.46s/it
# Iteratoin: 2867, [NLL, Log p(z), Log Det]: [-4.5335, -1.4154, 5.9489], 3.46s/it
# Iteratoin: 2868, [NLL, Log p(z), Log Det]: [-4.6726, -1.3868, 6.0594], 3.46s/it
# Iteratoin: 2869, [NLL, Log p(z), Log Det]: [-3.6997, -1.4051, 5.1048], 3.46s/it
# Iteratoin: 2870, [NLL, Log p(z), Log Det]: [-4.3811, -1.3738, 5.7549], 3.54s/it
# Iteratoin: 2871, [NLL, Log p(z), Log Det]: [-3.9516, -1.4554, 5.4070], 3.43s/it
# Iteratoin: 2872, [NLL, Log p(z), Log Det]: [-4.1157, -1.4381, 5.5538], 3.44s/it
# Iteratoin: 2873, [NLL, Log p(z), Log Det]: [-4.2975, -1.4038, 5.7013], 3.42s/it
# Iteratoin: 2874, [NLL, Log p(z), Log Det]: [-4.0075, -1.3945, 5.4020], 3.44s/it
# Iteratoin: 2875, [NLL, Log p(z), Log Det]: [-4.2881, -1.3501, 5.6382], 3.44s/it
# Iteratoin: 2876, [NLL, Log p(z), Log Det]: [-4.0765, -1.4008, 5.4773], 3.47s/it
# Iteratoin: 2877, [NLL, Log p(z), Log Det]: [-3.9469, -1.4022, 5.3491], 3.43s/it
# Iteratoin: 2878, [NLL, Log p(z), Log Det]: [-4.3654, -1.3882, 5.7536], 3.43s/it
# Iteratoin: 2879, [NLL, Log p(z), Log Det]: [-4.5571, -1.4460, 6.0031], 3.44s/it
# Iteratoin: 2880, [NLL, Log p(z), Log Det]: [-4.2019, -1.4462, 5.6481], 3.50s/it
# Iteratoin: 2881, [NLL, Log p(z), Log Det]: [-4.1421, -1.4082, 5.5503], 3.47s/it
# Iteratoin: 2882, [NLL, Log p(z), Log Det]: [-4.5269, -1.3709, 5.8978], 3.43s/it
# Iteratoin: 2883, [NLL, Log p(z), Log Det]: [-4.4677, -1.4479, 5.9156], 3.43s/it
# Iteratoin: 2884, [NLL, Log p(z), Log Det]: [-3.8620, -1.4189, 5.2809], 3.47s/it
# Iteratoin: 2885, [NLL, Log p(z), Log Det]: [-4.2147, -1.3729, 5.5876], 3.53s/it
# Iteratoin: 2886, [NLL, Log p(z), Log Det]: [-4.3686, -1.4476, 5.8161], 3.45s/it
# Iteratoin: 2887, [NLL, Log p(z), Log Det]: [-4.1851, -1.5014, 5.6865], 3.44s/it
# Iteratoin: 2888, [NLL, Log p(z), Log Det]: [-3.8072, -1.4662, 5.2734], 3.49s/it
# Iteratoin: 2889, [NLL, Log p(z), Log Det]: [-4.3065, -1.4483, 5.7548], 3.43s/it
# Iteratoin: 2890, [NLL, Log p(z), Log Det]: [-4.3100, -1.4223, 5.7323], 3.44s/it
# Iteratoin: 2891, [NLL, Log p(z), Log Det]: [-4.3239, -1.3441, 5.6680], 3.40s/it
# Iteratoin: 2892, [NLL, Log p(z), Log Det]: [-4.6189, -1.4763, 6.0952], 3.48s/it
# Iteratoin: 2893, [NLL, Log p(z), Log Det]: [-3.8398, -1.5231, 5.3629], 3.45s/it
# Iteratoin: 2894, [NLL, Log p(z), Log Det]: [-4.2638, -1.4559, 5.7196], 3.46s/it
# Iteratoin: 2895, [NLL, Log p(z), Log Det]: [-4.1632, -1.3906, 5.5538], 3.42s/it
# Iteratoin: 2896, [NLL, Log p(z), Log Det]: [-4.3338, -1.3914, 5.7253], 3.48s/it
# Iteratoin: 2897, [NLL, Log p(z), Log Det]: [-4.3542, -1.3733, 5.7275], 3.42s/it
# Iteratoin: 2898, [NLL, Log p(z), Log Det]: [-4.4132, -1.3815, 5.7947], 3.47s/it
# Iteratoin: 2899, [NLL, Log p(z), Log Det]: [-4.1917, -1.4316, 5.6233], 3.45s/it
# Iteratoin: 2900, [NLL, Log p(z), Log Det]: [-4.4937, -1.3917, 5.8855], 3.47s/it
# Iteratoin: 2901, [NLL, Log p(z), Log Det]: [-4.8561, -1.4035, 6.2596], 3.44s/it
# Iteratoin: 2902, [NLL, Log p(z), Log Det]: [-4.2241, -1.4735, 5.6976], 3.45s/it
# Iteratoin: 2903, [NLL, Log p(z), Log Det]: [-4.5811, -1.4296, 6.0108], 3.42s/it
# Iteratoin: 2904, [NLL, Log p(z), Log Det]: [-3.7830, -1.4280, 5.2110], 3.42s/it
# Iteratoin: 2905, [NLL, Log p(z), Log Det]: [-4.6549, -1.3499, 6.0048], 3.45s/it
# Iteratoin: 2906, [NLL, Log p(z), Log Det]: [-4.5877, -1.3078, 5.8955], 3.44s/it
# Iteratoin: 2907, [NLL, Log p(z), Log Det]: [-4.4542, -1.3271, 5.7813], 3.43s/it
# Iteratoin: 2908, [NLL, Log p(z), Log Det]: [-4.0872, -1.3866, 5.4737], 3.46s/it
# Iteratoin: 2909, [NLL, Log p(z), Log Det]: [-4.1970, -1.3932, 5.5902], 3.44s/it
# Iteratoin: 2910, [NLL, Log p(z), Log Det]: [-4.5774, -1.3876, 5.9650], 3.43s/it
# Iteratoin: 2911, [NLL, Log p(z), Log Det]: [-4.1759, -1.4076, 5.5835], 3.45s/it
# Iteratoin: 2912, [NLL, Log p(z), Log Det]: [-4.3573, -1.4340, 5.7912], 3.50s/it
# Iteratoin: 2913, [NLL, Log p(z), Log Det]: [-4.3455, -1.3810, 5.7265], 3.44s/it
# Iteratoin: 2914, [NLL, Log p(z), Log Det]: [-4.3357, -1.4156, 5.7513], 3.45s/it
# Iteratoin: 2915, [NLL, Log p(z), Log Det]: [-4.2659, -1.3741, 5.6401], 3.46s/it
# Iteratoin: 2916, [NLL, Log p(z), Log Det]: [-4.4044, -1.3876, 5.7919], 3.48s/it
# Iteratoin: 2917, [NLL, Log p(z), Log Det]: [-4.5202, -1.4680, 5.9882], 3.47s/it
# Iteratoin: 2918, [NLL, Log p(z), Log Det]: [-4.0915, -1.4715, 5.5630], 3.45s/it
# Iteratoin: 2919, [NLL, Log p(z), Log Det]: [-4.8686, -1.3879, 6.2565], 3.46s/it
# Iteratoin: 2920, [NLL, Log p(z), Log Det]: [-4.0001, -1.5236, 5.5237], 3.46s/it
# Iteratoin: 2921, [NLL, Log p(z), Log Det]: [-4.1424, -1.5604, 5.7028], 3.44s/it
# Iteratoin: 2922, [NLL, Log p(z), Log Det]: [-3.9962, -1.4660, 5.4622], 3.45s/it
# Iteratoin: 2923, [NLL, Log p(z), Log Det]: [-4.2519, -1.3954, 5.6473], 3.47s/it
# Iteratoin: 2924, [NLL, Log p(z), Log Det]: [-4.2628, -1.4391, 5.7019], 3.47s/it
# Iteratoin: 2925, [NLL, Log p(z), Log Det]: [-4.0584, -1.4638, 5.5223], 3.45s/it
# Iteratoin: 2926, [NLL, Log p(z), Log Det]: [-4.2329, -1.4076, 5.6404], 3.47s/it
# Iteratoin: 2927, [NLL, Log p(z), Log Det]: [-4.0214, -1.4474, 5.4688], 3.44s/it
# Iteratoin: 2928, [NLL, Log p(z), Log Det]: [-3.8890, -1.4556, 5.3446], 3.46s/it
# Iteratoin: 2929, [NLL, Log p(z), Log Det]: [-4.3475, -1.3855, 5.7330], 3.45s/it
# Iteratoin: 2930, [NLL, Log p(z), Log Det]: [-4.6846, -1.3395, 6.0241], 3.43s/it
# Iteratoin: 2931, [NLL, Log p(z), Log Det]: [-4.1493, -1.3492, 5.4985], 3.47s/it
# Iteratoin: 2932, [NLL, Log p(z), Log Det]: [-4.5825, -1.3412, 5.9237], 3.46s/it
# Iteratoin: 2933, [NLL, Log p(z), Log Det]: [-4.0460, -1.3965, 5.4425], 3.45s/it
# Iteratoin: 2934, [NLL, Log p(z), Log Det]: [-4.1751, -1.4565, 5.6317], 3.45s/it
# Iteratoin: 2935, [NLL, Log p(z), Log Det]: [-4.2403, -1.4348, 5.6751], 3.45s/it
# Iteratoin: 2936, [NLL, Log p(z), Log Det]: [-4.0895, -1.4592, 5.5487], 3.48s/it
# Iteratoin: 2937, [NLL, Log p(z), Log Det]: [-4.2879, -1.4174, 5.7052], 3.46s/it
# Iteratoin: 2938, [NLL, Log p(z), Log Det]: [-4.6648, -1.3897, 6.0545], 3.47s/it
# Iteratoin: 2939, [NLL, Log p(z), Log Det]: [-4.1187, -1.3636, 5.4823], 3.43s/it
# Iteratoin: 2940, [NLL, Log p(z), Log Det]: [-4.3832, -1.3701, 5.7533], 3.48s/it
# Iteratoin: 2941, [NLL, Log p(z), Log Det]: [-4.0338, -1.4143, 5.4481], 3.44s/it
# Iteratoin: 2942, [NLL, Log p(z), Log Det]: [-3.9923, -1.4364, 5.4288], 3.45s/it
# Iteratoin: 2943, [NLL, Log p(z), Log Det]: [-4.2600, -1.4711, 5.7311], 3.43s/it
# Iteratoin: 2944, [NLL, Log p(z), Log Det]: [-4.1441, -1.4260, 5.5701], 3.49s/it
# Iteratoin: 2945, [NLL, Log p(z), Log Det]: [-4.5274, -1.4230, 5.9504], 3.45s/it
# Iteratoin: 2946, [NLL, Log p(z), Log Det]: [-4.3529, -1.4844, 5.8373], 3.45s/it
# Iteratoin: 2947, [NLL, Log p(z), Log Det]: [-4.2845, -1.4230, 5.7075], 3.46s/it
# Iteratoin: 2948, [NLL, Log p(z), Log Det]: [-3.9440, -1.4244, 5.3683], 3.49s/it
# Iteratoin: 2949, [NLL, Log p(z), Log Det]: [-4.5451, -1.3618, 5.9069], 3.45s/it
# Iteratoin: 2950, [NLL, Log p(z), Log Det]: [-4.5120, -1.3776, 5.8896], 3.45s/it
# Iteratoin: 2951, [NLL, Log p(z), Log Det]: [-4.3519, -1.3907, 5.7426], 3.45s/it
# Iteratoin: 2952, [NLL, Log p(z), Log Det]: [-4.5368, -1.4421, 5.9789], 3.49s/it
# Iteratoin: 2953, [NLL, Log p(z), Log Det]: [-3.7031, -1.6436, 5.3466], 3.46s/it
# Iteratoin: 2954, [NLL, Log p(z), Log Det]: [-4.0984, -1.4869, 5.5854], 3.44s/it
# Iteratoin: 2955, [NLL, Log p(z), Log Det]: [-4.1305, -1.4004, 5.5309], 3.45s/it
# Iteratoin: 2956, [NLL, Log p(z), Log Det]: [-3.8264, -1.4858, 5.3123], 3.47s/it
# Iteratoin: 2957, [NLL, Log p(z), Log Det]: [-3.9913, -1.5185, 5.5097], 3.46s/it
# Iteratoin: 2958, [NLL, Log p(z), Log Det]: [-3.9317, -1.5027, 5.4344], 3.45s/it
# Iteratoin: 2959, [NLL, Log p(z), Log Det]: [-4.0967, -1.3655, 5.4622], 3.45s/it
# Iteratoin: 2960, [NLL, Log p(z), Log Det]: [-3.8130, -1.3934, 5.2064], 3.47s/it
# Iteratoin: 2961, [NLL, Log p(z), Log Det]: [-4.1670, -1.3735, 5.5405], 3.46s/it
# Iteratoin: 2962, [NLL, Log p(z), Log Det]: [-4.1978, -1.4544, 5.6522], 3.46s/it
# Iteratoin: 2963, [NLL, Log p(z), Log Det]: [-3.9384, -1.4827, 5.4212], 3.44s/it
# Iteratoin: 2964, [NLL, Log p(z), Log Det]: [-4.1383, -1.4797, 5.6180], 3.49s/it
# Iteratoin: 2965, [NLL, Log p(z), Log Det]: [-4.3444, -1.4242, 5.7686], 3.44s/it
# Iteratoin: 2966, [NLL, Log p(z), Log Det]: [-4.1253, -1.5201, 5.6454], 3.45s/it
# Iteratoin: 2967, [NLL, Log p(z), Log Det]: [-4.2032, -1.4217, 5.6249], 3.44s/it
# Iteratoin: 2968, [NLL, Log p(z), Log Det]: [-4.0470, -1.4115, 5.4585], 3.49s/it
# Iteratoin: 2969, [NLL, Log p(z), Log Det]: [-4.4462, -1.4204, 5.8666], 3.42s/it
# Iteratoin: 2970, [NLL, Log p(z), Log Det]: [-3.8188, -1.4212, 5.2400], 3.44s/it
# Iteratoin: 2971, [NLL, Log p(z), Log Det]: [-4.2104, -1.3984, 5.6088], 3.46s/it
# Iteratoin: 2972, [NLL, Log p(z), Log Det]: [-4.1752, -1.3828, 5.5579], 3.47s/it
# Iteratoin: 2973, [NLL, Log p(z), Log Det]: [-3.9303, -1.3764, 5.3067], 3.45s/it
# Iteratoin: 2974, [NLL, Log p(z), Log Det]: [-4.1924, -1.3438, 5.5362], 3.45s/it
# Iteratoin: 2975, [NLL, Log p(z), Log Det]: [-4.4913, -1.3474, 5.8387], 3.44s/it
# Iteratoin: 2976, [NLL, Log p(z), Log Det]: [-4.1833, -1.4112, 5.5945], 3.48s/it
# Iteratoin: 2977, [NLL, Log p(z), Log Det]: [-4.5583, -1.4203, 5.9786], 3.47s/it
# Iteratoin: 2978, [NLL, Log p(z), Log Det]: [-3.8842, -1.4194, 5.3036], 3.46s/it
# Iteratoin: 2979, [NLL, Log p(z), Log Det]: [-4.0858, -1.4622, 5.5480], 3.42s/it
# Iteratoin: 2980, [NLL, Log p(z), Log Det]: [-4.3325, -1.4587, 5.7911], 3.47s/it
# Iteratoin: 2981, [NLL, Log p(z), Log Det]: [-4.2408, -1.4667, 5.7076], 3.46s/it
# Iteratoin: 2982, [NLL, Log p(z), Log Det]: [-4.5351, -1.4315, 5.9666], 3.44s/it
# Iteratoin: 2983, [NLL, Log p(z), Log Det]: [-4.7853, -1.3836, 6.1688], 3.46s/it
# Iteratoin: 2984, [NLL, Log p(z), Log Det]: [-4.3645, -1.3582, 5.7227], 3.48s/it
# Iteratoin: 2985, [NLL, Log p(z), Log Det]: [-4.7258, -1.3829, 6.1087], 3.46s/it
# Iteratoin: 2986, [NLL, Log p(z), Log Det]: [-4.0244, -1.3339, 5.3583], 3.44s/it
# Iteratoin: 2987, [NLL, Log p(z), Log Det]: [-4.6351, -1.4014, 6.0366], 3.43s/it
# Iteratoin: 2988, [NLL, Log p(z), Log Det]: [-4.3142, -1.5577, 5.8720], 3.48s/it
# Iteratoin: 2989, [NLL, Log p(z), Log Det]: [-4.3525, -1.5248, 5.8773], 3.46s/it
# Iteratoin: 2990, [NLL, Log p(z), Log Det]: [-4.0397, -1.5707, 5.6105], 3.45s/it
# Iteratoin: 2991, [NLL, Log p(z), Log Det]: [-3.9781, -1.5682, 5.5463], 3.47s/it
# Iteratoin: 2992, [NLL, Log p(z), Log Det]: [-3.9529, -1.4774, 5.4302], 3.47s/it
# Iteratoin: 2993, [NLL, Log p(z), Log Det]: [-3.9361, -1.5921, 5.5283], 3.48s/it
# Iteratoin: 2994, [NLL, Log p(z), Log Det]: [-3.8638, -1.6755, 5.5393], 3.43s/it
# Iteratoin: 2995, [NLL, Log p(z), Log Det]: [-3.8444, -1.6168, 5.4612], 3.42s/it
# Iteratoin: 2996, [NLL, Log p(z), Log Det]: [-4.2061, -1.3285, 5.5345], 3.48s/it
# Iteratoin: 2997, [NLL, Log p(z), Log Det]: [-3.9440, -1.3721, 5.3161], 3.44s/it
# Iteratoin: 2998, [NLL, Log p(z), Log Det]: [-3.7078, -1.3475, 5.0553], 3.45s/it
# Iteratoin: 2999, [NLL, Log p(z), Log Det]: [-4.0878, -1.3437, 5.4315], 3.47s/it
# Iteratoin: 3000, [NLL, Log p(z), Log Det]: [-3.7302, -1.4439, 5.1741], 3.48s/it
# Iteratoin: 3001, [NLL, Log p(z), Log Det]: [-3.8861, -1.5292, 5.4153], 3.47s/it
# Iteratoin: 3002, [NLL, Log p(z), Log Det]: [-4.1013, -1.5253, 5.6266], 3.43s/it
# Iteratoin: 3003, [NLL, Log p(z), Log Det]: [-3.6135, -1.5548, 5.1684], 3.43s/it
# Iteratoin: 3004, [NLL, Log p(z), Log Det]: [-3.9863, -1.4835, 5.4698], 3.49s/it
# Iteratoin: 3005, [NLL, Log p(z), Log Det]: [-4.7378, -1.4486, 6.1864], 3.44s/it
# Iteratoin: 3006, [NLL, Log p(z), Log Det]: [-3.9931, -1.3873, 5.3804], 3.44s/it
# Iteratoin: 3007, [NLL, Log p(z), Log Det]: [-4.0513, -1.3929, 5.4441], 3.47s/it
# Iteratoin: 3008, [NLL, Log p(z), Log Det]: [-3.9555, -1.3618, 5.3173], 3.47s/it
# Iteratoin: 3009, [NLL, Log p(z), Log Det]: [-4.4656, -1.3043, 5.7699], 3.45s/it
# Iteratoin: 3010, [NLL, Log p(z), Log Det]: [-4.1704, -1.3535, 5.5239], 3.44s/it
# Iteratoin: 3011, [NLL, Log p(z), Log Det]: [-3.9680, -1.3430, 5.3111], 3.46s/it
# Iteratoin: 3012, [NLL, Log p(z), Log Det]: [-4.2504, -1.3822, 5.6326], 3.46s/it
# Iteratoin: 3013, [NLL, Log p(z), Log Det]: [-3.9530, -1.4576, 5.4106], 3.45s/it
# Iteratoin: 3014, [NLL, Log p(z), Log Det]: [-4.1078, -1.4501, 5.5579], 3.45s/it
# Iteratoin: 3015, [NLL, Log p(z), Log Det]: [-4.2877, -1.3910, 5.6786], 3.45s/it
# Iteratoin: 3016, [NLL, Log p(z), Log Det]: [-4.2788, -1.4432, 5.7220], 3.48s/it
# Iteratoin: 3017, [NLL, Log p(z), Log Det]: [-4.1540, -1.3658, 5.5197], 3.45s/it
# Iteratoin: 3018, [NLL, Log p(z), Log Det]: [-4.1987, -1.3774, 5.5761], 3.46s/it
# Iteratoin: 3019, [NLL, Log p(z), Log Det]: [-3.9202, -1.3374, 5.2576], 3.44s/it
# Iteratoin: 3020, [NLL, Log p(z), Log Det]: [-4.0707, -1.4512, 5.5219], 3.48s/it
# Iteratoin: 3021, [NLL, Log p(z), Log Det]: [-4.1228, -1.4583, 5.5810], 3.44s/it
# Iteratoin: 3022, [NLL, Log p(z), Log Det]: [-4.2915, -1.4379, 5.7294], 3.46s/it
# Iteratoin: 3023, [NLL, Log p(z), Log Det]: [-4.0376, -1.4520, 5.4895], 3.45s/it
# Iteratoin: 3024, [NLL, Log p(z), Log Det]: [-4.1624, -1.4361, 5.5984], 3.49s/it
# Iteratoin: 3025, [NLL, Log p(z), Log Det]: [-4.2735, -1.3949, 5.6684], 3.45s/it
# Iteratoin: 3026, [NLL, Log p(z), Log Det]: [-4.0915, -1.4135, 5.5051], 3.44s/it
# Iteratoin: 3027, [NLL, Log p(z), Log Det]: [-4.1520, -1.4367, 5.5886], 3.45s/it
# Iteratoin: 3028, [NLL, Log p(z), Log Det]: [-4.1233, -1.3891, 5.5124], 3.48s/it
# Iteratoin: 3029, [NLL, Log p(z), Log Det]: [-4.0444, -1.3726, 5.4170], 3.48s/it
# Iteratoin: 3030, [NLL, Log p(z), Log Det]: [-4.4032, -1.3909, 5.7941], 3.46s/it
# Iteratoin: 3031, [NLL, Log p(z), Log Det]: [-4.1030, -1.3917, 5.4947], 3.43s/it
# Iteratoin: 3032, [NLL, Log p(z), Log Det]: [-4.5814, -1.3528, 5.9342], 3.48s/it
# Iteratoin: 3033, [NLL, Log p(z), Log Det]: [-4.1976, -1.4269, 5.6244], 3.45s/it
# Iteratoin: 3034, [NLL, Log p(z), Log Det]: [-4.1831, -1.4135, 5.5967], 3.43s/it
# Iteratoin: 3035, [NLL, Log p(z), Log Det]: [-4.5102, -1.4632, 5.9734], 3.45s/it
# Iteratoin: 3036, [NLL, Log p(z), Log Det]: [-4.1239, -1.4695, 5.5935], 3.47s/it
# Iteratoin: 3037, [NLL, Log p(z), Log Det]: [-4.4229, -1.3900, 5.8129], 3.47s/it
# Iteratoin: 3038, [NLL, Log p(z), Log Det]: [-4.3727, -1.4294, 5.8021], 3.44s/it
# Iteratoin: 3039, [NLL, Log p(z), Log Det]: [-4.1802, -1.4092, 5.5894], 3.41s/it
# Iteratoin: 3040, [NLL, Log p(z), Log Det]: [-5.0113, -1.3811, 6.3924], 3.44s/it
# Iteratoin: 3041, [NLL, Log p(z), Log Det]: [-4.1302, -1.4669, 5.5971], 3.42s/it
# Iteratoin: 3042, [NLL, Log p(z), Log Det]: [-4.2826, -1.4432, 5.7258], 3.44s/it
# Iteratoin: 3043, [NLL, Log p(z), Log Det]: [-3.8671, -1.4390, 5.3062], 3.40s/it
# Iteratoin: 3044, [NLL, Log p(z), Log Det]: [-4.0010, -1.4246, 5.4257], 3.45s/it
# Iteratoin: 3045, [NLL, Log p(z), Log Det]: [-4.2689, -1.4187, 5.6876], 3.44s/it
# Iteratoin: 3046, [NLL, Log p(z), Log Det]: [-4.3963, -1.3448, 5.7411], 3.46s/it
# Iteratoin: 3047, [NLL, Log p(z), Log Det]: [-4.0399, -1.4005, 5.4403], 3.44s/it
# Iteratoin: 3048, [NLL, Log p(z), Log Det]: [-4.4341, -1.3882, 5.8222], 3.47s/it
# Iteratoin: 3049, [NLL, Log p(z), Log Det]: [-4.4359, -1.3819, 5.8178], 3.46s/it
# Iteratoin: 3050, [NLL, Log p(z), Log Det]: [-3.9372, -1.3910, 5.3282], 3.44s/it
# Iteratoin: 3051, [NLL, Log p(z), Log Det]: [-4.2862, -1.3825, 5.6688], 3.45s/it
# Iteratoin: 3052, [NLL, Log p(z), Log Det]: [-3.8442, -1.4984, 5.3426], 3.47s/it
# Iteratoin: 3053, [NLL, Log p(z), Log Det]: [-4.2671, -1.5275, 5.7945], 3.46s/it
# Iteratoin: 3054, [NLL, Log p(z), Log Det]: [-4.3134, -1.4136, 5.7270], 3.45s/it
# Iteratoin: 3055, [NLL, Log p(z), Log Det]: [-4.3796, -1.4193, 5.7989], 3.45s/it
# Iteratoin: 3056, [NLL, Log p(z), Log Det]: [-4.1944, -1.4912, 5.6856], 3.49s/it
# Iteratoin: 3057, [NLL, Log p(z), Log Det]: [-4.3483, -1.3873, 5.7356], 3.44s/it
# Iteratoin: 3058, [NLL, Log p(z), Log Det]: [-4.2440, -1.4114, 5.6553], 3.45s/it
# Iteratoin: 3059, [NLL, Log p(z), Log Det]: [-4.0047, -1.4704, 5.4751], 3.40s/it
# Iteratoin: 3060, [NLL, Log p(z), Log Det]: [-4.3624, -1.4182, 5.7805], 3.43s/it
# Iteratoin: 3061, [NLL, Log p(z), Log Det]: [-4.0554, -1.4607, 5.5161], 3.45s/it
# Iteratoin: 3062, [NLL, Log p(z), Log Det]: [-4.4731, -1.4473, 5.9204], 3.42s/it
# Iteratoin: 3063, [NLL, Log p(z), Log Det]: [-4.5172, -1.4853, 6.0025], 3.40s/it
# Iteratoin: 3064, [NLL, Log p(z), Log Det]: [-4.3413, -1.4660, 5.8073], 3.46s/it
# Iteratoin: 3065, [NLL, Log p(z), Log Det]: [-4.0153, -1.4259, 5.4413], 3.44s/it
# Iteratoin: 3066, [NLL, Log p(z), Log Det]: [-4.2467, -1.3655, 5.6122], 3.45s/it
# Iteratoin: 3067, [NLL, Log p(z), Log Det]: [-4.2547, -1.3833, 5.6380], 3.44s/it
# Iteratoin: 3068, [NLL, Log p(z), Log Det]: [-4.2503, -1.3735, 5.6238], 3.48s/it
# Iteratoin: 3069, [NLL, Log p(z), Log Det]: [-4.1520, -1.3945, 5.5464], 3.44s/it
# Iteratoin: 3070, [NLL, Log p(z), Log Det]: [-4.2246, -1.4159, 5.6405], 3.45s/it
# Iteratoin: 3071, [NLL, Log p(z), Log Det]: [-4.3195, -1.3977, 5.7171], 3.47s/it
# Iteratoin: 3072, [NLL, Log p(z), Log Det]: [-4.1175, -1.3505, 5.4681], 3.48s/it
# Iteratoin: 3073, [NLL, Log p(z), Log Det]: [-4.0500, -1.4006, 5.4506], 3.47s/it
# Iteratoin: 3074, [NLL, Log p(z), Log Det]: [-4.1338, -1.3816, 5.5154], 3.44s/it
# Iteratoin: 3075, [NLL, Log p(z), Log Det]: [-3.9814, -1.4039, 5.3854], 3.44s/it
# Iteratoin: 3076, [NLL, Log p(z), Log Det]: [-4.1207, -1.3977, 5.5184], 3.46s/it
# Iteratoin: 3077, [NLL, Log p(z), Log Det]: [-4.4078, -1.4326, 5.8404], 3.46s/it
# Iteratoin: 3078, [NLL, Log p(z), Log Det]: [-4.1814, -1.4607, 5.6420], 3.45s/it
# Iteratoin: 3079, [NLL, Log p(z), Log Det]: [-4.9564, -1.4623, 6.4188], 3.39s/it
# Iteratoin: 3080, [NLL, Log p(z), Log Det]: [-4.3109, -1.5393, 5.8502], 3.45s/it
# Iteratoin: 3081, [NLL, Log p(z), Log Det]: [-3.9940, -1.4719, 5.4659], 3.46s/it
# Iteratoin: 3082, [NLL, Log p(z), Log Det]: [-4.1274, -1.4284, 5.5558], 3.43s/it
# Iteratoin: 3083, [NLL, Log p(z), Log Det]: [-4.2298, -1.4602, 5.6900], 3.43s/it
# Iteratoin: 3084, [NLL, Log p(z), Log Det]: [-4.2280, -1.4195, 5.6475], 3.47s/it
# Iteratoin: 3085, [NLL, Log p(z), Log Det]: [-4.5042, -1.3123, 5.8165], 3.46s/it
# Iteratoin: 3086, [NLL, Log p(z), Log Det]: [-3.9072, -1.3949, 5.3020], 3.44s/it
# Iteratoin: 3087, [NLL, Log p(z), Log Det]: [-4.3039, -1.3986, 5.7025], 3.47s/it
# Iteratoin: 3088, [NLL, Log p(z), Log Det]: [-4.2453, -1.3904, 5.6358], 3.46s/it
# Iteratoin: 3089, [NLL, Log p(z), Log Det]: [-4.5080, -1.3814, 5.8893], 3.46s/it
# Iteratoin: 3090, [NLL, Log p(z), Log Det]: [-4.2160, -1.3787, 5.5947], 3.44s/it
# Iteratoin: 3091, [NLL, Log p(z), Log Det]: [-4.3421, -1.4128, 5.7549], 3.46s/it
# Iteratoin: 3092, [NLL, Log p(z), Log Det]: [-4.3163, -1.4308, 5.7471], 3.48s/it
# Iteratoin: 3093, [NLL, Log p(z), Log Det]: [-3.8683, -1.4740, 5.3423], 3.47s/it
# Iteratoin: 3094, [NLL, Log p(z), Log Det]: [-4.0029, -1.4929, 5.4958], 3.43s/it
# Iteratoin: 3095, [NLL, Log p(z), Log Det]: [-4.0159, -1.4571, 5.4730], 3.44s/it
# Iteratoin: 3096, [NLL, Log p(z), Log Det]: [-4.1356, -1.4340, 5.5696], 3.48s/it
# Iteratoin: 3097, [NLL, Log p(z), Log Det]: [-4.1323, -1.3912, 5.5235], 3.45s/it
# Iteratoin: 3098, [NLL, Log p(z), Log Det]: [-4.2379, -1.3996, 5.6375], 3.46s/it
# Iteratoin: 3099, [NLL, Log p(z), Log Det]: [-4.1752, -1.3871, 5.5623], 3.47s/it
# Iteratoin: 3100, [NLL, Log p(z), Log Det]: [-4.3306, -1.3537, 5.6843], 3.45s/it
# Iteratoin: 3101, [NLL, Log p(z), Log Det]: [-4.1619, -1.4085, 5.5704], 3.56s/it
# Iteratoin: 3102, [NLL, Log p(z), Log Det]: [-4.3122, -1.3795, 5.6918], 3.44s/it
# Iteratoin: 3103, [NLL, Log p(z), Log Det]: [-4.2291, -1.4312, 5.6603], 3.45s/it
# Iteratoin: 3104, [NLL, Log p(z), Log Det]: [-4.1560, -1.3567, 5.5127], 3.47s/it
# Iteratoin: 3105, [NLL, Log p(z), Log Det]: [-4.2688, -1.3768, 5.6456], 3.45s/it
# Iteratoin: 3106, [NLL, Log p(z), Log Det]: [-4.3679, -1.3789, 5.7469], 3.48s/it
# Iteratoin: 3107, [NLL, Log p(z), Log Det]: [-3.8913, -1.4344, 5.3257], 3.44s/it
# Iteratoin: 3108, [NLL, Log p(z), Log Det]: [-4.3469, -1.4192, 5.7661], 3.49s/it
# Iteratoin: 3109, [NLL, Log p(z), Log Det]: [-4.3987, -1.3998, 5.7985], 3.45s/it
# Iteratoin: 3110, [NLL, Log p(z), Log Det]: [-4.2491, -1.4263, 5.6755], 3.48s/it
# Iteratoin: 3111, [NLL, Log p(z), Log Det]: [-4.2222, -1.4672, 5.6894], 3.42s/it
# Iteratoin: 3112, [NLL, Log p(z), Log Det]: [-4.0123, -1.4108, 5.4231], 3.47s/it
# Iteratoin: 3113, [NLL, Log p(z), Log Det]: [-3.9282, -1.3727, 5.3009], 3.46s/it
# Iteratoin: 3114, [NLL, Log p(z), Log Det]: [-4.5053, -1.4160, 5.9213], 3.45s/it
# Iteratoin: 3115, [NLL, Log p(z), Log Det]: [-4.2103, -1.4635, 5.6738], 3.45s/it
# Iteratoin: 3116, [NLL, Log p(z), Log Det]: [-4.7405, -1.4864, 6.2269], 3.48s/it
# Iteratoin: 3117, [NLL, Log p(z), Log Det]: [-3.8000, -1.5706, 5.3705], 3.43s/it
# Iteratoin: 3118, [NLL, Log p(z), Log Det]: [-4.1054, -1.4235, 5.5289], 3.45s/it
# Iteratoin: 3119, [NLL, Log p(z), Log Det]: [-4.2901, -1.3670, 5.6571], 3.46s/it
# Iteratoin: 3120, [NLL, Log p(z), Log Det]: [-4.1013, -1.4041, 5.5054], 3.51s/it
# Iteratoin: 3121, [NLL, Log p(z), Log Det]: [-4.0922, -1.3820, 5.4743], 3.47s/it
# Iteratoin: 3122, [NLL, Log p(z), Log Det]: [-3.8653, -1.4588, 5.3240], 3.43s/it
# Iteratoin: 3123, [NLL, Log p(z), Log Det]: [-4.0723, -1.5013, 5.5736], 3.43s/it
# Iteratoin: 3124, [NLL, Log p(z), Log Det]: [-3.9986, -1.4728, 5.4714], 3.46s/it
# Iteratoin: 3125, [NLL, Log p(z), Log Det]: [-4.3353, -1.4362, 5.7715], 3.44s/it
# Iteratoin: 3126, [NLL, Log p(z), Log Det]: [-4.4003, -1.4375, 5.8378], 3.45s/it
# Iteratoin: 3127, [NLL, Log p(z), Log Det]: [-4.0088, -1.4192, 5.4280], 3.46s/it
# Iteratoin: 3128, [NLL, Log p(z), Log Det]: [-4.1565, -1.4221, 5.5786], 3.46s/it
# Iteratoin: 3129, [NLL, Log p(z), Log Det]: [-4.1663, -1.4506, 5.6169], 3.45s/it
# Iteratoin: 3130, [NLL, Log p(z), Log Det]: [-4.2244, -1.3950, 5.6194], 3.45s/it
# Iteratoin: 3131, [NLL, Log p(z), Log Det]: [-4.2668, -1.3833, 5.6501], 3.46s/it
# Iteratoin: 3132, [NLL, Log p(z), Log Det]: [-4.1944, -1.3728, 5.5671], 3.43s/it
# Iteratoin: 3133, [NLL, Log p(z), Log Det]: [-4.2833, -1.3822, 5.6655], 3.37s/it
# Iteratoin: 3134, [NLL, Log p(z), Log Det]: [-3.9355, -1.3958, 5.3313], 3.37s/it
# Iteratoin: 3135, [NLL, Log p(z), Log Det]: [-4.0300, -1.4047, 5.4348], 3.44s/it
# Iteratoin: 3136, [NLL, Log p(z), Log Det]: [-4.0768, -1.4309, 5.5077], 3.48s/it
# Iteratoin: 3137, [NLL, Log p(z), Log Det]: [-4.0102, -1.4325, 5.4427], 3.47s/it
# Iteratoin: 3138, [NLL, Log p(z), Log Det]: [-4.0095, -1.4117, 5.4212], 3.45s/it
# Iteratoin: 3139, [NLL, Log p(z), Log Det]: [-3.9819, -1.4201, 5.4020], 3.41s/it
# Iteratoin: 3140, [NLL, Log p(z), Log Det]: [-4.4967, -1.3727, 5.8693], 3.45s/it
# Iteratoin: 3141, [NLL, Log p(z), Log Det]: [-3.9996, -1.3921, 5.3917], 3.44s/it
# Iteratoin: 3142, [NLL, Log p(z), Log Det]: [-4.3202, -1.3275, 5.6477], 3.46s/it
# Iteratoin: 3143, [NLL, Log p(z), Log Det]: [-3.9680, -1.3827, 5.3507], 3.45s/it
# Iteratoin: 3144, [NLL, Log p(z), Log Det]: [-4.0746, -1.4126, 5.4872], 3.47s/it
# Iteratoin: 3145, [NLL, Log p(z), Log Det]: [-4.2763, -1.4454, 5.7217], 3.46s/it
# Iteratoin: 3146, [NLL, Log p(z), Log Det]: [-3.7080, -1.4765, 5.1845], 3.43s/it
# Iteratoin: 3147, [NLL, Log p(z), Log Det]: [-4.3849, -1.4376, 5.8225], 3.47s/it
# Iteratoin: 3148, [NLL, Log p(z), Log Det]: [-3.9358, -1.4771, 5.4129], 3.46s/it
# Iteratoin: 3149, [NLL, Log p(z), Log Det]: [-4.3374, -1.4657, 5.8031], 3.47s/it
# Iteratoin: 3150, [NLL, Log p(z), Log Det]: [-4.2873, -1.4186, 5.7059], 3.42s/it
# Iteratoin: 3151, [NLL, Log p(z), Log Det]: [-4.0388, -1.3917, 5.4305], 3.35s/it
# Iteratoin: 3152, [NLL, Log p(z), Log Det]: [-4.2076, -1.3631, 5.5707], 3.38s/it
# Iteratoin: 3153, [NLL, Log p(z), Log Det]: [-4.4190, -1.3956, 5.8147], 3.39s/it
# Iteratoin: 3154, [NLL, Log p(z), Log Det]: [-4.2732, -1.4598, 5.7330], 3.37s/it
# Iteratoin: 3155, [NLL, Log p(z), Log Det]: [-4.2156, -1.4406, 5.6562], 3.36s/it
# Iteratoin: 3156, [NLL, Log p(z), Log Det]: [-4.2943, -1.5059, 5.8002], 3.38s/it
# Iteratoin: 3157, [NLL, Log p(z), Log Det]: [-4.3508, -1.4937, 5.8445], 3.36s/it
# Iteratoin: 3158, [NLL, Log p(z), Log Det]: [-4.4076, -1.4170, 5.8246], 3.37s/it
# Iteratoin: 3159, [NLL, Log p(z), Log Det]: [-4.4707, -1.4070, 5.8777], 3.35s/it
# Iteratoin: 3160, [NLL, Log p(z), Log Det]: [-4.1645, -1.4322, 5.5967], 3.37s/it
# Iteratoin: 3161, [NLL, Log p(z), Log Det]: [-4.3471, -1.3974, 5.7446], 3.39s/it
# Iteratoin: 3162, [NLL, Log p(z), Log Det]: [-4.2532, -1.4003, 5.6535], 3.35s/it
# Iteratoin: 3163, [NLL, Log p(z), Log Det]: [-3.9787, -1.3927, 5.3714], 3.34s/it
# Iteratoin: 3164, [NLL, Log p(z), Log Det]: [-4.3204, -1.3601, 5.6806], 3.41s/it
# Iteratoin: 3165, [NLL, Log p(z), Log Det]: [-4.3047, -1.3385, 5.6432], 3.40s/it
# Iteratoin: 3166, [NLL, Log p(z), Log Det]: [-4.0573, -1.3718, 5.4291], 3.36s/it
# Iteratoin: 3167, [NLL, Log p(z), Log Det]: [-4.4498, -1.4119, 5.8617], 3.34s/it
# Iteratoin: 3168, [NLL, Log p(z), Log Det]: [-4.2119, -1.3838, 5.5957], 3.38s/it
# Iteratoin: 3169, [NLL, Log p(z), Log Det]: [-4.4018, -1.4177, 5.8195], 3.39s/it
# Iteratoin: 3170, [NLL, Log p(z), Log Det]: [-4.4201, -1.4507, 5.8709], 3.36s/it
# Iteratoin: 3171, [NLL, Log p(z), Log Det]: [-4.4778, -1.4628, 5.9407], 3.35s/it
# Iteratoin: 3172, [NLL, Log p(z), Log Det]: [-4.4129, -1.4217, 5.8346], 3.38s/it
# Iteratoin: 3173, [NLL, Log p(z), Log Det]: [-4.3404, -1.4618, 5.8022], 3.39s/it
# Iteratoin: 3174, [NLL, Log p(z), Log Det]: [-4.1338, -1.4760, 5.6098], 3.36s/it
# Iteratoin: 3175, [NLL, Log p(z), Log Det]: [-4.5114, -1.4160, 5.9274], 3.38s/it
# Iteratoin: 3176, [NLL, Log p(z), Log Det]: [-4.9249, -1.3895, 6.3145], 3.38s/it
# Iteratoin: 3177, [NLL, Log p(z), Log Det]: [-4.2210, -1.4058, 5.6268], 3.36s/it
# Iteratoin: 3178, [NLL, Log p(z), Log Det]: [-4.1806, -1.3925, 5.5731], 3.37s/it
# Iteratoin: 3179, [NLL, Log p(z), Log Det]: [-4.0724, -1.4095, 5.4820], 3.35s/it
# Iteratoin: 3180, [NLL, Log p(z), Log Det]: [-4.0807, -1.4654, 5.5462], 3.39s/it
# Iteratoin: 3181, [NLL, Log p(z), Log Det]: [-4.4537, -1.4620, 5.9157], 3.39s/it
# Iteratoin: 3182, [NLL, Log p(z), Log Det]: [-3.8863, -1.5731, 5.4594], 3.36s/it
# Iteratoin: 3183, [NLL, Log p(z), Log Det]: [-4.0792, -1.4021, 5.4814], 3.35s/it
# Iteratoin: 3184, [NLL, Log p(z), Log Det]: [-4.3173, -1.3911, 5.7083], 3.38s/it
# Iteratoin: 3185, [NLL, Log p(z), Log Det]: [-4.3589, -1.3864, 5.7453], 3.39s/it
# Iteratoin: 3186, [NLL, Log p(z), Log Det]: [-4.3661, -1.5490, 5.9151], 3.38s/it
# Iteratoin: 3187, [NLL, Log p(z), Log Det]: [-4.2272, -1.4431, 5.6702], 3.34s/it
# Iteratoin: 3188, [NLL, Log p(z), Log Det]: [-4.3028, -1.4216, 5.7244], 3.37s/it
# Iteratoin: 3189, [NLL, Log p(z), Log Det]: [-4.2952, -1.3791, 5.6743], 3.38s/it
# Iteratoin: 3190, [NLL, Log p(z), Log Det]: [-3.9943, -1.3742, 5.3684], 3.38s/it
# Iteratoin: 3191, [NLL, Log p(z), Log Det]: [-4.0954, -1.3973, 5.4927], 3.36s/it
# Iteratoin: 3192, [NLL, Log p(z), Log Det]: [-4.5877, -1.4068, 5.9945], 3.40s/it
# Iteratoin: 3193, [NLL, Log p(z), Log Det]: [-4.1981, -1.4630, 5.6611], 3.37s/it
# Iteratoin: 3194, [NLL, Log p(z), Log Det]: [-4.5201, -1.5028, 6.0230], 3.37s/it
# Iteratoin: 3195, [NLL, Log p(z), Log Det]: [-4.2183, -1.4999, 5.7183], 3.36s/it
# Iteratoin: 3196, [NLL, Log p(z), Log Det]: [-4.2107, -1.4393, 5.6500], 3.38s/it
# Iteratoin: 3197, [NLL, Log p(z), Log Det]: [-4.0212, -1.3926, 5.4138], 3.38s/it
# Iteratoin: 3198, [NLL, Log p(z), Log Det]: [-4.2060, -1.3706, 5.5765], 3.37s/it
# Iteratoin: 3199, [NLL, Log p(z), Log Det]: [-4.3026, -1.3541, 5.6568], 3.36s/it
# Iteratoin: 3200, [NLL, Log p(z), Log Det]: [-4.4614, -1.3520, 5.8134], 3.40s/it
# Iteratoin: 3201, [NLL, Log p(z), Log Det]: [-4.0899, -1.4172, 5.5071], 3.39s/it
# Iteratoin: 3202, [NLL, Log p(z), Log Det]: [-4.0099, -1.4152, 5.4251], 3.39s/it
# Iteratoin: 3203, [NLL, Log p(z), Log Det]: [-4.1958, -1.3739, 5.5698], 3.33s/it
# Iteratoin: 3204, [NLL, Log p(z), Log Det]: [-4.3136, -1.3625, 5.6761], 3.38s/it
# Iteratoin: 3205, [NLL, Log p(z), Log Det]: [-4.2312, -1.4114, 5.6426], 3.37s/it
# Iteratoin: 3206, [NLL, Log p(z), Log Det]: [-5.0741, -1.3828, 6.4569], 3.36s/it
# Iteratoin: 3207, [NLL, Log p(z), Log Det]: [-4.1722, -1.4286, 5.6008], 3.36s/it
# Iteratoin: 3208, [NLL, Log p(z), Log Det]: [-4.0013, -1.4517, 5.4530], 3.37s/it
# Iteratoin: 3209, [NLL, Log p(z), Log Det]: [-4.4564, -1.4298, 5.8861], 3.37s/it
# Iteratoin: 3210, [NLL, Log p(z), Log Det]: [-4.4215, -1.4194, 5.8409], 3.40s/it
# Iteratoin: 3211, [NLL, Log p(z), Log Det]: [-4.7601, -1.4134, 6.1736], 3.33s/it
# Iteratoin: 3212, [NLL, Log p(z), Log Det]: [-4.0358, -1.4723, 5.5081], 3.38s/it
# Iteratoin: 3213, [NLL, Log p(z), Log Det]: [-4.1101, -1.4018, 5.5119], 3.37s/it
# Iteratoin: 3214, [NLL, Log p(z), Log Det]: [-4.5306, -1.4103, 5.9409], 3.39s/it
# Iteratoin: 3215, [NLL, Log p(z), Log Det]: [-4.5456, -1.3615, 5.9071], 3.46s/it
# Iteratoin: 3216, [NLL, Log p(z), Log Det]: [-4.5286, -1.3612, 5.8897], 3.47s/it
# Iteratoin: 3217, [NLL, Log p(z), Log Det]: [-4.5603, -1.3651, 5.9254], 3.44s/it
# Iteratoin: 3218, [NLL, Log p(z), Log Det]: [-4.4316, -1.3627, 5.7942], 3.44s/it
# Iteratoin: 3219, [NLL, Log p(z), Log Det]: [-4.3912, -1.3861, 5.7773], 3.46s/it
# Iteratoin: 3220, [NLL, Log p(z), Log Det]: [-4.2739, -1.4355, 5.7094], 3.48s/it
# Iteratoin: 3221, [NLL, Log p(z), Log Det]: [-3.9179, -1.4699, 5.3878], 3.44s/it
# Iteratoin: 3222, [NLL, Log p(z), Log Det]: [-4.4546, -1.4324, 5.8870], 3.47s/it
# Iteratoin: 3223, [NLL, Log p(z), Log Det]: [-4.1793, -1.4453, 5.6247], 3.44s/it
# Iteratoin: 3224, [NLL, Log p(z), Log Det]: [-4.1031, -1.4312, 5.5343], 3.48s/it
# Iteratoin: 3225, [NLL, Log p(z), Log Det]: [-4.3980, -1.4081, 5.8061], 3.46s/it
# Iteratoin: 3226, [NLL, Log p(z), Log Det]: [-4.0775, -1.4405, 5.5180], 3.47s/it
# Iteratoin: 3227, [NLL, Log p(z), Log Det]: [-4.0124, -1.4388, 5.4512], 3.44s/it
# Iteratoin: 3228, [NLL, Log p(z), Log Det]: [-3.9905, -1.3834, 5.3739], 3.49s/it
# ...
# Iteratoin: 7426, [NLL, Log p(z), Log Det]: [-4.2009, -1.4467, 5.6476], 3.40s/it
# Iteratoin: 7427, [NLL, Log p(z), Log Det]: [-4.3471, -1.4138, 5.7609], 3.38s/it
# Iteratoin: 7428, [NLL, Log p(z), Log Det]: [-4.5756, -1.3898, 5.9654], 3.37s/it
# Iteratoin: 7429, [NLL, Log p(z), Log Det]: [-4.1871, -1.4089, 5.5959], 3.38s/it
# Iteratoin: 7430, [NLL, Log p(z), Log Det]: [-4.5976, -1.3951, 5.9927], 3.39s/it
# Iteratoin: 7431, [NLL, Log p(z), Log Det]: [-4.0440, -1.4321, 5.4760], 3.37s/it
# Iteratoin: 7432, [NLL, Log p(z), Log Det]: [-4.4833, -1.3802, 5.8635], 3.39s/it
# Iteratoin: 7433, [NLL, Log p(z), Log Det]: [-4.6288, -1.3937, 6.0225], 3.38s/it
# Iteratoin: 7434, [NLL, Log p(z), Log Det]: [-4.5246, -1.4099, 5.9344], 3.40s/it
# Iteratoin: 7435, [NLL, Log p(z), Log Det]: [-4.2345, -1.3980, 5.6324], 3.36s/it
# Iteratoin: 7436, [NLL, Log p(z), Log Det]: [-4.7699, -1.3964, 6.1663], 3.38s/it
# Iteratoin: 7437, [NLL, Log p(z), Log Det]: [-4.5810, -1.3797, 5.9608], 3.40s/it
# Iteratoin: 7438, [NLL, Log p(z), Log Det]: [-4.6778, -1.4020, 6.0798], 3.36s/it
# Iteratoin: 7439, [NLL, Log p(z), Log Det]: [-4.3108, -1.4063, 5.7171], 3.35s/it
# Iteratoin: 7440, [NLL, Log p(z), Log Det]: [-4.1761, -1.4180, 5.5941], 3.39s/it
# Iteratoin: 7441, [NLL, Log p(z), Log Det]: [-4.4383, -1.3905, 5.8288], 3.37s/it
# Iteratoin: 7442, [NLL, Log p(z), Log Det]: [-4.3238, -1.3866, 5.7104], 3.39s/it
# Iteratoin: 7443, [NLL, Log p(z), Log Det]: [-4.6234, -1.3909, 6.0143], 3.37s/it
# Iteratoin: 7444, [NLL, Log p(z), Log Det]: [-4.6046, -1.4306, 6.0352], 3.41s/it
# Iteratoin: 7445, [NLL, Log p(z), Log Det]: [-4.5052, -1.4267, 5.9319], 3.37s/it
# Iteratoin: 7446, [NLL, Log p(z), Log Det]: [-4.2471, -1.4053, 5.6524], 3.38s/it
# Iteratoin: 7447, [NLL, Log p(z), Log Det]: [-4.1141, -1.3854, 5.4995], 3.36s/it
# Iteratoin: 7448, [NLL, Log p(z), Log Det]: [-4.3726, -1.3994, 5.7720], 3.36s/it
# Iteratoin: 7449, [NLL, Log p(z), Log Det]: [-4.3784, -1.4455, 5.8239], 3.36s/it
# Iteratoin: 7450, [NLL, Log p(z), Log Det]: [-4.3475, -1.4434, 5.7909], 3.36s/it
# Iteratoin: 7451, [NLL, Log p(z), Log Det]: [-4.5277, -1.3913, 5.9190], 3.36s/it
# Iteratoin: 7452, [NLL, Log p(z), Log Det]: [-4.4138, -1.4189, 5.8327], 3.38s/it
# Iteratoin: 7453, [NLL, Log p(z), Log Det]: [-4.1169, -1.4043, 5.5212], 3.36s/it
# Iteratoin: 7454, [NLL, Log p(z), Log Det]: [-4.4055, -1.4434, 5.8489], 3.36s/it
# Iteratoin: 7455, [NLL, Log p(z), Log Det]: [-4.4433, -1.4553, 5.8986], 3.35s/it
# Iteratoin: 7456, [NLL, Log p(z), Log Det]: [-4.3182, -1.4024, 5.7206], 3.40s/it
# Iteratoin: 7457, [NLL, Log p(z), Log Det]: [-4.0699, -1.4537, 5.5236], 3.36s/it
# Iteratoin: 7458, [NLL, Log p(z), Log Det]: [-4.8929, -1.4162, 6.3091], 3.35s/it
# Iteratoin: 7459, [NLL, Log p(z), Log Det]: [-4.3452, -1.4231, 5.7683], 3.34s/it
# Iteratoin: 7460, [NLL, Log p(z), Log Det]: [-4.5203, -1.4251, 5.9454], 3.38s/it
# Iteratoin: 7461, [NLL, Log p(z), Log Det]: [-4.3831, -1.4684, 5.8515], 3.41s/it
# Iteratoin: 7462, [NLL, Log p(z), Log Det]: [-4.1672, -1.4577, 5.6249], 3.39s/it
# Iteratoin: 7463, [NLL, Log p(z), Log Det]: [-4.3918, -1.4039, 5.7957], 3.35s/it
# Iteratoin: 7464, [NLL, Log p(z), Log Det]: [-5.2100, -1.3600, 6.5700], 3.39s/it
# Iteratoin: 7465, [NLL, Log p(z), Log Det]: [-4.1398, -1.3978, 5.5376], 3.40s/it
# Iteratoin: 7466, [NLL, Log p(z), Log Det]: [-4.2718, -1.3872, 5.6589], 3.38s/it
# Iteratoin: 7467, [NLL, Log p(z), Log Det]: [-4.8081, -1.4184, 6.2265], 3.38s/it
# Iteratoin: 7468, [NLL, Log p(z), Log Det]: [-4.5500, -1.4145, 5.9646], 3.39s/it
# Iteratoin: 7469, [NLL, Log p(z), Log Det]: [-4.9642, -1.5028, 6.4670], 3.36s/it
# Iteratoin: 7470, [NLL, Log p(z), Log Det]: [-4.5291, -1.4918, 6.0209], 3.39s/it
# Iteratoin: 7471, [NLL, Log p(z), Log Det]: [-4.1403, -1.4635, 5.6038], 3.38s/it
# Iteratoin: 7472, [NLL, Log p(z), Log Det]: [-4.7587, -1.4002, 6.1589], 3.39s/it
# Iteratoin: 7473, [NLL, Log p(z), Log Det]: [-4.4441, -1.5001, 5.9442], 3.46s/it
# Iteratoin: 7474, [NLL, Log p(z), Log Det]: [-4.3229, -1.5121, 5.8350], 3.38s/it
# Iteratoin: 7475, [NLL, Log p(z), Log Det]: [-4.5390, -1.3936, 5.9326], 3.37s/it
# Iteratoin: 7476, [NLL, Log p(z), Log Det]: [-4.3289, -1.4074, 5.7363], 3.47s/it
# Iteratoin: 7477, [NLL, Log p(z), Log Det]: [-4.2599, -1.4172, 5.6771], 3.43s/it
# Iteratoin: 7478, [NLL, Log p(z), Log Det]: [-4.5224, -1.3818, 5.9041], 3.42s/it
# Iteratoin: 7479, [NLL, Log p(z), Log Det]: [-4.6762, -1.3963, 6.0725], 3.41s/it
# Iteratoin: 7480, [NLL, Log p(z), Log Det]: [-4.6684, -1.4475, 6.1159], 3.46s/it
# Iteratoin: 7481, [NLL, Log p(z), Log Det]: [-3.9991, -1.4747, 5.4738], 3.43s/it
# Iteratoin: 7482, [NLL, Log p(z), Log Det]: [-4.4787, -1.4249, 5.9037], 3.42s/it
# Iteratoin: 7483, [NLL, Log p(z), Log Det]: [-4.7400, -1.3957, 6.1357], 3.41s/it
# Iteratoin: 7484, [NLL, Log p(z), Log Det]: [-4.8998, -1.3800, 6.2798], 3.42s/it
# Iteratoin: 7485, [NLL, Log p(z), Log Det]: [-4.6448, -1.3750, 6.0199], 3.41s/it
# Iteratoin: 7486, [NLL, Log p(z), Log Det]: [-4.8753, -1.3441, 6.2194], 3.41s/it
# Iteratoin: 7487, [NLL, Log p(z), Log Det]: [-4.3816, -1.3755, 5.7571], 3.45s/it
# Iteratoin: 7488, [NLL, Log p(z), Log Det]: [-4.5124, -1.4082, 5.9206], 3.48s/it
# Iteratoin: 7489, [NLL, Log p(z), Log Det]: [-3.9952, -1.4259, 5.4210], 3.44s/it
# Iteratoin: 7490, [NLL, Log p(z), Log Det]: [-4.2244, -1.4236, 5.6480], 3.44s/it
# Iteratoin: 7491, [NLL, Log p(z), Log Det]: [-5.0466, -1.3972, 6.4438], 3.45s/it
# Iteratoin: 7492, [NLL, Log p(z), Log Det]: [-4.5554, -1.4187, 5.9741], 3.46s/it
# Iteratoin: 7493, [NLL, Log p(z), Log Det]: [-4.6796, -1.4398, 6.1194], 3.46s/it
# Iteratoin: 7494, [NLL, Log p(z), Log Det]: [-4.3252, -1.4366, 5.7617], 3.47s/it
# Iteratoin: 7495, [NLL, Log p(z), Log Det]: [-4.2754, -1.4346, 5.7099], 3.44s/it
# Iteratoin: 7496, [NLL, Log p(z), Log Det]: [-4.4682, -1.3834, 5.8517], 3.47s/it
# Iteratoin: 7497, [NLL, Log p(z), Log Det]: [-4.6519, -1.4404, 6.0923], 3.43s/it
# Iteratoin: 7498, [NLL, Log p(z), Log Det]: [-4.3003, -1.4108, 5.7111], 3.45s/it
# Iteratoin: 7499, [NLL, Log p(z), Log Det]: [-4.6924, -1.3984, 6.0907], 3.44s/it
# Iteratoin: 7500, [NLL, Log p(z), Log Det]: [-4.1904, -1.3906, 5.5810], 3.49s/it
# Iteratoin: 7501, [NLL, Log p(z), Log Det]: [-4.8130, -1.4107, 6.2237], 3.42s/it
# Iteratoin: 7502, [NLL, Log p(z), Log Det]: [-4.2513, -1.4076, 5.6589], 3.49s/it
# Iteratoin: 7503, [NLL, Log p(z), Log Det]: [-4.4700, -1.4147, 5.8847], 3.45s/it
# Iteratoin: 7504, [NLL, Log p(z), Log Det]: [-4.3700, -1.4112, 5.7812], 3.46s/it
# Iteratoin: 7505, [NLL, Log p(z), Log Det]: [-4.5061, -1.4361, 5.9422], 3.45s/it
# Iteratoin: 7506, [NLL, Log p(z), Log Det]: [-4.6654, -1.4414, 6.1068], 3.47s/it
# Iteratoin: 7507, [NLL, Log p(z), Log Det]: [-4.3952, -1.4353, 5.8305], 3.42s/it
# Iteratoin: 7508, [NLL, Log p(z), Log Det]: [-4.5729, -1.4149, 5.9878], 3.45s/it
# Iteratoin: 7509, [NLL, Log p(z), Log Det]: [-4.4458, -1.4126, 5.8585], 3.44s/it
# Iteratoin: 7510, [NLL, Log p(z), Log Det]: [-4.5838, -1.4795, 6.0633], 3.45s/it
# Iteratoin: 7511, [NLL, Log p(z), Log Det]: [-4.6677, -1.4793, 6.1471], 3.45s/it
# Iteratoin: 7512, [NLL, Log p(z), Log Det]: [-4.8889, -1.4106, 6.2995], 3.47s/it
# Iteratoin: 7513, [NLL, Log p(z), Log Det]: [-4.5229, -1.3890, 5.9119], 3.47s/it
# Iteratoin: 7514, [NLL, Log p(z), Log Det]: [-4.2256, -1.3711, 5.5967], 3.49s/it
# Iteratoin: 7515, [NLL, Log p(z), Log Det]: [-4.4448, -1.3864, 5.8312], 3.46s/it
# Iteratoin: 7516, [NLL, Log p(z), Log Det]: [-4.6071, -1.3804, 5.9875], 3.46s/it
# Iteratoin: 7517, [NLL, Log p(z), Log Det]: [-5.0239, -1.4165, 6.4404], 3.46s/it
# Iteratoin: 7518, [NLL, Log p(z), Log Det]: [-4.2258, -1.4379, 5.6637], 3.47s/it
# Iteratoin: 7519, [NLL, Log p(z), Log Det]: [-4.8196, -1.4214, 6.2410], 3.44s/it
# Iteratoin: 7520, [NLL, Log p(z), Log Det]: [-4.4804, -1.4127, 5.8931], 3.52s/it
# Iteratoin: 7521, [NLL, Log p(z), Log Det]: [-4.4916, -1.3957, 5.8874], 3.45s/it
# Iteratoin: 7522, [NLL, Log p(z), Log Det]: [-4.9368, -1.3663, 6.3031], 3.45s/it
# Iteratoin: 7523, [NLL, Log p(z), Log Det]: [-4.4693, -1.4529, 5.9221], 3.43s/it
# Iteratoin: 7524, [NLL, Log p(z), Log Det]: [-4.3207, -1.4514, 5.7721], 3.50s/it
# Iteratoin: 7525, [NLL, Log p(z), Log Det]: [-4.8282, -1.4754, 6.3037], 3.44s/it
# Iteratoin: 7526, [NLL, Log p(z), Log Det]: [-4.6463, -1.4809, 6.1272], 3.47s/it
# Iteratoin: 7527, [NLL, Log p(z), Log Det]: [-4.7502, -1.4235, 6.1737], 3.43s/it
# Iteratoin: 7528, [NLL, Log p(z), Log Det]: [-4.5284, -1.3972, 5.9255], 3.47s/it
# Iteratoin: 7529, [NLL, Log p(z), Log Det]: [-4.7912, -1.4690, 6.2602], 3.48s/it
# Iteratoin: 7530, [NLL, Log p(z), Log Det]: [-4.4698, -1.3893, 5.8591], 3.47s/it
# Iteratoin: 7531, [NLL, Log p(z), Log Det]: [-4.6049, -1.3983, 6.0031], 3.46s/it
# Iteratoin: 7532, [NLL, Log p(z), Log Det]: [-4.9976, -1.4115, 6.4090], 3.48s/it
# Iteratoin: 7533, [NLL, Log p(z), Log Det]: [-4.5602, -1.4316, 5.9918], 3.49s/it
# Iteratoin: 7534, [NLL, Log p(z), Log Det]: [-4.7817, -1.4273, 6.2089], 3.45s/it
# Iteratoin: 7535, [NLL, Log p(z), Log Det]: [-4.8417, -1.4099, 6.2516], 3.46s/it
# Iteratoin: 7536, [NLL, Log p(z), Log Det]: [-4.6592, -1.4357, 6.0949], 3.47s/it
# Iteratoin: 7537, [NLL, Log p(z), Log Det]: [-4.8842, -1.3713, 6.2555], 3.49s/it
# Iteratoin: 7538, [NLL, Log p(z), Log Det]: [-4.5922, -1.4028, 5.9949], 3.48s/it
# Iteratoin: 7539, [NLL, Log p(z), Log Det]: [-4.8856, -1.3727, 6.2583], 3.46s/it
# Iteratoin: 7540, [NLL, Log p(z), Log Det]: [-4.2585, -1.4079, 5.6665], 3.49s/it
# Iteratoin: 7541, [NLL, Log p(z), Log Det]: [-4.7286, -1.4695, 6.1981], 3.49s/it
# Iteratoin: 7542, [NLL, Log p(z), Log Det]: [-4.6867, -1.4772, 6.1638], 3.48s/it
# Iteratoin: 7543, [NLL, Log p(z), Log Det]: [-4.0629, -1.4771, 5.5400], 3.44s/it
# Iteratoin: 7544, [NLL, Log p(z), Log Det]: [-4.4405, -1.4378, 5.8783], 3.50s/it
# Iteratoin: 7545, [NLL, Log p(z), Log Det]: [-4.4489, -1.4483, 5.8972], 3.51s/it
# Iteratoin: 7546, [NLL, Log p(z), Log Det]: [-4.4300, -1.3835, 5.8135], 3.50s/it
# Iteratoin: 7547, [NLL, Log p(z), Log Det]: [-4.4108, -1.4039, 5.8147], 3.45s/it
# Iteratoin: 7548, [NLL, Log p(z), Log Det]: [-4.6002, -1.3823, 5.9824], 3.45s/it
# Iteratoin: 7549, [NLL, Log p(z), Log Det]: [-4.7546, -1.3952, 6.1498], 3.47s/it
# Iteratoin: 7550, [NLL, Log p(z), Log Det]: [-4.4570, -1.3797, 5.8367], 3.42s/it
# Iteratoin: 7551, [NLL, Log p(z), Log Det]: [-4.4275, -1.4434, 5.8709], 3.37s/it
# Iteratoin: 7552, [NLL, Log p(z), Log Det]: [-4.8223, -1.4070, 6.2294], 3.48s/it
# Iteratoin: 7553, [NLL, Log p(z), Log Det]: [-4.3473, -1.4508, 5.7981], 3.45s/it
# Iteratoin: 7554, [NLL, Log p(z), Log Det]: [-4.2478, -1.4377, 5.6855], 3.43s/it
# Iteratoin: 7555, [NLL, Log p(z), Log Det]: [-4.6777, -1.4390, 6.1167], 3.41s/it
# Iteratoin: 7556, [NLL, Log p(z), Log Det]: [-4.8058, -1.4770, 6.2828], 3.43s/it
# Iteratoin: 7557, [NLL, Log p(z), Log Det]: [-4.9994, -1.5098, 6.5092], 3.43s/it
# Iteratoin: 7558, [NLL, Log p(z), Log Det]: [-4.0015, -1.5110, 5.5125], 3.46s/it
# Iteratoin: 7559, [NLL, Log p(z), Log Det]: [-4.5712, -1.4024, 5.9736], 3.44s/it
# Iteratoin: 7560, [NLL, Log p(z), Log Det]: [-4.5834, -1.4114, 5.9948], 3.45s/it
# Iteratoin: 7561, [NLL, Log p(z), Log Det]: [-4.3987, -1.3775, 5.7762], 3.45s/it
# Iteratoin: 7562, [NLL, Log p(z), Log Det]: [-4.8919, -1.3486, 6.2405], 3.42s/it
# Iteratoin: 7563, [NLL, Log p(z), Log Det]: [-4.7197, -1.3544, 6.0741], 3.39s/it
# Iteratoin: 7564, [NLL, Log p(z), Log Det]: [-4.2692, -1.4370, 5.7062], 3.44s/it
# Iteratoin: 7565, [NLL, Log p(z), Log Det]: [-5.0226, -1.3856, 6.4082], 3.46s/it
# Iteratoin: 7566, [NLL, Log p(z), Log Det]: [-4.3470, -1.3949, 5.7419], 3.46s/it
# Iteratoin: 7567, [NLL, Log p(z), Log Det]: [-4.3723, -1.3546, 5.7269], 3.40s/it
# Iteratoin: 7568, [NLL, Log p(z), Log Det]: [-4.1609, -1.4121, 5.5729], 3.42s/it
# Iteratoin: 7569, [NLL, Log p(z), Log Det]: [-4.1766, -1.4131, 5.5897], 3.44s/it
# Iteratoin: 7570, [NLL, Log p(z), Log Det]: [-4.3575, -1.3964, 5.7540], 3.43s/it
# Iteratoin: 7571, [NLL, Log p(z), Log Det]: [-4.6309, -1.3845, 6.0154], 3.45s/it
# Iteratoin: 7572, [NLL, Log p(z), Log Det]: [-4.6030, -1.3965, 5.9995], 3.43s/it
# Iteratoin: 7573, [NLL, Log p(z), Log Det]: [-4.4852, -1.3926, 5.8779], 3.41s/it
# Iteratoin: 7574, [NLL, Log p(z), Log Det]: [-4.3503, -1.3932, 5.7435], 3.44s/it
# Iteratoin: 7575, [NLL, Log p(z), Log Det]: [-4.5076, -1.3982, 5.9058], 3.44s/it
# Iteratoin: 7576, [NLL, Log p(z), Log Det]: [-4.6154, -1.4155, 6.0308], 3.48s/it
# Iteratoin: 7577, [NLL, Log p(z), Log Det]: [-4.7291, -1.4076, 6.1368], 3.41s/it
# Iteratoin: 7578, [NLL, Log p(z), Log Det]: [-4.1853, -1.4213, 5.6066], 3.45s/it
# Iteratoin: 7579, [NLL, Log p(z), Log Det]: [-4.9303, -1.4580, 6.3883], 3.44s/it
# Iteratoin: 7580, [NLL, Log p(z), Log Det]: [-5.1907, -1.4616, 6.6524], 3.46s/it
# Iteratoin: 7581, [NLL, Log p(z), Log Det]: [-4.1764, -1.5484, 5.7249], 3.47s/it
# Iteratoin: 7582, [NLL, Log p(z), Log Det]: [-4.4142, -1.4490, 5.8632], 3.43s/it
# Iteratoin: 7583, [NLL, Log p(z), Log Det]: [-4.4159, -1.4158, 5.8317], 3.43s/it
# Iteratoin: 7584, [NLL, Log p(z), Log Det]: [-4.5439, -1.4101, 5.9540], 3.47s/it
# Iteratoin: 7585, [NLL, Log p(z), Log Det]: [-4.1623, -1.4055, 5.5679], 3.45s/it
# Iteratoin: 7586, [NLL, Log p(z), Log Det]: [-4.3830, -1.4037, 5.7867], 3.44s/it
# Iteratoin: 7587, [NLL, Log p(z), Log Det]: [-4.4384, -1.4143, 5.8527], 3.45s/it
# Iteratoin: 7588, [NLL, Log p(z), Log Det]: [-4.4173, -1.4385, 5.8558], 3.48s/it
# Iteratoin: 7589, [NLL, Log p(z), Log Det]: [-4.3438, -1.4191, 5.7629], 3.46s/it
# Iteratoin: 7590, [NLL, Log p(z), Log Det]: [-4.8554, -1.4229, 6.2783], 3.53s/it
# Iteratoin: 7591, [NLL, Log p(z), Log Det]: [-4.6779, -1.4455, 6.1234], 3.44s/it
# Iteratoin: 7592, [NLL, Log p(z), Log Det]: [-4.3824, -1.4334, 5.8158], 3.48s/it
# Iteratoin: 7593, [NLL, Log p(z), Log Det]: [-4.3192, -1.4279, 5.7471], 3.42s/it
# Iteratoin: 7594, [NLL, Log p(z), Log Det]: [-4.4673, -1.4655, 5.9328], 3.39s/it
# Iteratoin: 7595, [NLL, Log p(z), Log Det]: [-4.3304, -1.4261, 5.7565], 3.36s/it
# Iteratoin: 7596, [NLL, Log p(z), Log Det]: [-4.7570, -1.3866, 6.1436], 3.41s/it
# Iteratoin: 7597, [NLL, Log p(z), Log Det]: [-4.3463, -1.4057, 5.7520], 3.40s/it
# Iteratoin: 7598, [NLL, Log p(z), Log Det]: [-4.5972, -1.3565, 5.9537], 3.41s/it
# Iteratoin: 7599, [NLL, Log p(z), Log Det]: [-4.3796, -1.4004, 5.7799], 3.37s/it
# Iteratoin: 7600, [NLL, Log p(z), Log Det]: [-4.5606, -1.3614, 5.9220], 3.38s/it
# Iteratoin: 7601, [NLL, Log p(z), Log Det]: [-4.5440, -1.3787, 5.9227], 3.42s/it
# Iteratoin: 7602, [NLL, Log p(z), Log Det]: [-4.6180, -1.4118, 6.0298], 3.38s/it
# Iteratoin: 7603, [NLL, Log p(z), Log Det]: [-4.4293, -1.4413, 5.8706], 3.36s/it
# Iteratoin: 7604, [NLL, Log p(z), Log Det]: [-4.8686, -1.4501, 6.3186], 3.38s/it
# Iteratoin: 7605, [NLL, Log p(z), Log Det]: [-4.3752, -1.4688, 5.8440], 3.42s/it
# Iteratoin: 7606, [NLL, Log p(z), Log Det]: [-4.4554, -1.4251, 5.8805], 3.37s/it
# Iteratoin: 7607, [NLL, Log p(z), Log Det]: [-4.2546, -1.4280, 5.6826], 3.36s/it
# Iteratoin: 7608, [NLL, Log p(z), Log Det]: [-4.5244, -1.4225, 5.9469], 3.40s/it
# Iteratoin: 7609, [NLL, Log p(z), Log Det]: [-4.7306, -1.3883, 6.1188], 3.38s/it
# Iteratoin: 7610, [NLL, Log p(z), Log Det]: [-4.4410, -1.3988, 5.8399], 3.40s/it
# Iteratoin: 7611, [NLL, Log p(z), Log Det]: [-4.6637, -1.3766, 6.0403], 3.36s/it
# Iteratoin: 7612, [NLL, Log p(z), Log Det]: [-4.3381, -1.3955, 5.7335], 3.39s/it
# Iteratoin: 7613, [NLL, Log p(z), Log Det]: [-4.4467, -1.3853, 5.8320], 3.40s/it
# Iteratoin: 7614, [NLL, Log p(z), Log Det]: [-4.3830, -1.4150, 5.7980], 3.39s/it
# Iteratoin: 7615, [NLL, Log p(z), Log Det]: [-4.2911, -1.4071, 5.6982], 3.38s/it
# Iteratoin: 7616, [NLL, Log p(z), Log Det]: [-4.4365, -1.3967, 5.8332], 3.38s/it
# Iteratoin: 7617, [NLL, Log p(z), Log Det]: [-4.3886, -1.4121, 5.8007], 3.39s/it
# Iteratoin: 7618, [NLL, Log p(z), Log Det]: [-4.5939, -1.4484, 6.0423], 3.38s/it
# Iteratoin: 7619, [NLL, Log p(z), Log Det]: [-4.4118, -1.4653, 5.8772], 3.36s/it
# Iteratoin: 7620, [NLL, Log p(z), Log Det]: [-4.8854, -1.3971, 6.2825], 3.38s/it
# Iteratoin: 7621, [NLL, Log p(z), Log Det]: [-4.7637, -1.4212, 6.1849], 3.41s/it
# Iteratoin: 7622, [NLL, Log p(z), Log Det]: [-4.5995, -1.4149, 6.0144], 3.39s/it
# Iteratoin: 7623, [NLL, Log p(z), Log Det]: [-4.3540, -1.4144, 5.7684], 3.35s/it
# Iteratoin: 7624, [NLL, Log p(z), Log Det]: [-4.6117, -1.3866, 5.9983], 3.40s/it
# Iteratoin: 7625, [NLL, Log p(z), Log Det]: [-4.6956, -1.3912, 6.0868], 3.38s/it
